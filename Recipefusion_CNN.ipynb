# %%
import os
import pandas as pd
import requests

# %%
def download_image(image_url, output_directory):
    try:
        response = requests.get(image_url, stream=True)
        if response.status_code == 200:
            with open(output_directory, 'wb') as file:
                file.write(response.content)
            return True
        else:
            print(f"Failed to download image from {image_url}. Status code: {response.status_code}")
            return False
    except Exception as e:
        print(f"An error occurred while downloading image from {image_url}: {str(e)}")
        return False

# %%
def download_recipe_images(data, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    if 'image_url' not in data.columns:
        print("Error: 'image_url' column not found in the dataset.")
        return

    for index, row in data.iterrows():
        image_url = row['image_url']
        image_filename = f"{index}.jpg"
        image_path = os.path.join(output_directory, image_filename)

        if download_image(image_url, image_path):
            print(f"Downloaded image {index}: {image_url}")
        else:
            print(f"Failed to download image {index}: {image_url}")

    print("Image download process completed.")

# %%
# Example usage
# Assuming 'recipes.csv' is your dataset containing 'image_url' column
# and you want to download images to 'images' directory
dataset_path = 'fusionrecipe.csv'
output_directory = 'recfus_img'

# Load the dataset
data = pd.read_csv(dataset_path)

# %%
# Download recipe images
download_recipe_images(data, output_directory)
# Out:
# Downloaded image 0: https://media.istockphoto.com/id/691985214/photo/homemade-deep-fried-indian-flatbread.jpg?s=612x612&w=0&k=20&c=ppXX9cvP4SUOSaI4xlSqRuqGzeURvVEzWV2u3ZKpVbQ=
# Downloaded image 1: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1207175/dscf3709_full.jpg
# Downloaded image 2: https://s3.amazonaws.com/grecipes/public/pictures/recipes/37540/cabbage_salad_full.jpg
# Downloaded image 3: http://grecipes.s3.amazonaws.com/recipe_picture/1498249/full_uploads_20140617T0730Z_ace0df8560959563e0c5dc2af698b2da_shepuchi_bhaji3.jpg
# Downloaded image 4: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1229240/beetroot%20cutlet%20-%201_full.jpg
# Downloaded image 5: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1137932/dsc04540_full.jpg
# Downloaded image 6: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1093441/gajarkahalwa_full.jpg
# Downloaded image 7: http://grecipes.s3.amazonaws.com/recipe_picture/1501128/full_uploads_20140710T0641Z_b725a107b1484f4defc76757eeba63e0_IMG_7177.jpg
# Downloaded image 8: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1409113/befunky_dscn6959edited.jpg_full.jpg
# Downloaded image 9: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1137942/dsc04499_full.jpg
# Downloaded image 10: http://grecipes.s3.amazonaws.com/recipe_picture/1512110/full_doodhi_thepla1.jpg
# Downloaded image 11: https://s3.amazonaws.com/grecipes/public/pictures/recipes/821928/pav_bhaji_full.jpg
# Downloaded image 12: https://healthynibblesandbits.com/wp-content/uploads/2020/01/Saag-Paneer-FF.jpg
# Downloaded image 13: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1061865/img_5341_full.jpg
# Downloaded image 14: http://grecipes.s3.amazonaws.com/recipe_picture/1626512/full_uploads_20200911T1347Z_b289ba95a260bff325d18c4f7d0902d9_Jeera-aloo-foodpanda.jpg
# Downloaded image 15: https://img-global.cpcdn.com/recipes/2f8496835725af3d/680x482cq70/veggies-delight-pizza-recipe-main-photo.webp
# Downloaded image 16: https://beingnutritious.com/wp-content/uploads/2022/11/Stuffed-Mushrooms-9-scaled.jpg
# Downloaded image 17: https://i0.wp.com/faithfulplateful.com/wp-content/uploads/2018/11/lentil-vegetable-soup-1620160-scaled.jpg?resize=600%2C912&ssl=1
# Downloaded image 18: https://media.istockphoto.com/id/478249440/photo/tabbouleh-salad-with-quinoa-parsley-and-vegetables.jpg?s=612x612&w=0&k=20&c=zktRYgRomMrXb3dDdx-4-UFFG2gK-d-N6kmMaQCJjqQ=
# Downloaded image 19: https://www.easycheesyvegetarian.com/wp-content/uploads/2023/06/chickpea-stir-fry-7-1024x1536.jpg
# Downloaded image 20: https://cdn.loveandlemons.com/wp-content/uploads/2019/09/eggplant-parmesan.jpg
# Downloaded image 21: https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F43%2F2023%2F01%2F30%2F14041-delicious-black-bean-burritos-ddmfs-3x2-008.jpg&q=60&c=sc&poi=auto&orient=true&h=512
# Downloaded image 22: https://www.shutterstock.com/image-photo/stack-spanakopita-piece-pie-homemade-260nw-2378970187.jpg
# Downloaded image 23: https://cdn.loveandlemons.com/wp-content/uploads/2023/01/mushroom-risotto-recipe.jpg
# Downloaded image 24: https://cdn.loveandlemons.com/wp-content/uploads/2021/08/caprese-skewers-1.jpg
# Downloaded image 25: http://grecipes.s3.amazonaws.com/recipe_picture/1423988/full_vegetarian-chilli-shepherds-pie-from-the-oven.jpg
# Downloaded image 26: http://grecipes.s3.amazonaws.com/recipe_picture/1501938/full_ds_20140716T1436Z_da9cbeae31c1e180f402d896f04bc145_Stir_fried_vegetarian_mutton_453x640_453x640_.jpg
# Downloaded image 27: http://grecipes.s3.amazonaws.com/recipe_picture/1451914/full_no-guilt-chile.jpg
# Downloaded image 28: http://grecipes.s3.amazonaws.com/recipe_picture/1501940/full_uploads_20140716T1448Z_7abdcee1ce339b51f57f93368dfba42e_vegetarian_mutton_nasi_lemak_390x400_.jpg
# Downloaded image 29: http://grecipes.s3.amazonaws.com/recipe_picture/1512713/full_uploads_20141013T1743Z_8692fa5f1657892c3dda88e8baaf0c34_IMG_5604.JPG
# Downloaded image 30: https://s3.amazonaws.com/grecipes/public/pictures/recipes/373127/marrow_full.jpg
# Downloaded image 31: http://grecipes.s3.amazonaws.com/recipe_picture/1588224/full_uploads_20171207T0219Z_f377c615aea3336737a3c0d5a503d6db_GreenBeanCarrotMushroomMedleyP1010846.JPG
# Downloaded image 32: http://grecipes.s3.amazonaws.com/recipe_picture/1519097/full_TVP_spaghetti_sauce.png
# Downloaded image 33: https://s3.amazonaws.com/grecipes/public/pictures/recipes/861183/potato-skins_full.jpg
# Downloaded image 34: http://grecipes.s3.amazonaws.com/recipe_picture/1502423/full_uploads_20140720T1813Z_1f4510895473deaee36ddd20c7563ff2_2.jpg
# Downloaded image 35: http://grecipes.s3.amazonaws.com/recipe_picture/1442551/full_vegetarian-chili.jpg
# Downloaded image 36: http://grecipes.s3.amazonaws.com/recipe_picture/1516161/full_uploads_20141110T0258Z_6d8be58f0d89d4b3bb063d05151a6353_vegetarian_fried_mee_hoon.jpg
# Downloaded image 37: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1060435/mohanthal_full.jpg
# Downloaded image 38: https://s3.amazonaws.com/grecipes/public/pictures/recipes/504121/vege_tofu_stir_fry_full.jpg
# Downloaded image 39: https://s3.amazonaws.com/grecipes/public/pictures/recipes/39365/basmati_rice_full.jpg
# Downloaded image 40: https://s3.amazonaws.com/grecipes/public/pictures/recipes/754253/onion_bhajis0004_full.jpg
# Downloaded image 41: https://www.shutterstock.com/image-photo/monsoon-special-moong-dal-vada-600nw-1933277675.jpg
# Downloaded image 42: https://s3.amazonaws.com/grecipes/public/pictures/recipes/433297/malai_kofta1_full.jpg
# Downloaded image 43: https://s3.amazonaws.com/grecipes/public/pictures/recipes/865570/tepla__1__full.jpg
# Downloaded image 44: https://s3.amazonaws.com/grecipes/public/pictures/recipes/915438/atta_chakuli_full.jpg
# Downloaded image 45: http://grecipes.s3.amazonaws.com/recipe_picture/1498246/full_uploads_20140617T0726Z_b63f2d2358b7a90a6485f2df4408440b_masale_bhat1.jpg
# Downloaded image 46: http://grecipes.s3.amazonaws.com/recipe_picture/1439516/full_aamras-puri2.jpg
# Downloaded image 47: http://grecipes.s3.amazonaws.com/recipe_picture/1531584/full_Kesar_Pista_Kulfi3.jpg
# Downloaded image 48: https://s3.amazonaws.com/grecipes/public/pictures/recipes/9297/dry_potatoes_full.jpg
# Downloaded image 49: http://grecipes.s3.amazonaws.com/recipe_picture/1566114/uploads_20160823T0415Z_c5638816c58b3258f2d0463a8a5f239c_kesar-peda-indian-spicyvegrecipes.jpg
# Downloaded image 50: http://grecipes.s3.amazonaws.com/recipe_picture/1426198/522976-332658606801992-41013208-n.jpg
# Downloaded image 51: http://grecipes.s3.amazonaws.com/recipe_picture/1556987/0dfc088de82286d61309d9_Easy_Rock_Cheese_Toast_-_Crispy_Veg_Rava_Appetizer_Quick_Suji_Bread_Toast.jpg
# Downloaded image 52: http://grecipes.s3.amazonaws.com/recipe_picture/1516213/Nankhatai_Recipe_How_To_Make_Nankhatai_Eggless_Indian_Cookies.JPG
# Downloaded image 53: https://s3.amazonaws.com/grecipes/public/pictures/recipes/896013/scrap.jpg
# Downloaded image 54: https://2.bp.blogspot.com/-XBnc8RVmaRQ/UQP4uwoIMFI/AAAAAAAAL2I/OBNDg5krYME/s1600/IMG_2458.jpg
# Downloaded image 55: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free49.jpg
# Downloaded image 56: https://2.bp.blogspot.com/-F9iGc1iUrkw/TppUWBWpp0I/AAAAAAAABu8/y4iVIAtlze4/s1600/P1040905.JPG
# Downloaded image 57: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free322.jpg
# Downloaded image 58: http://grecipes.s3.amazonaws.com/recipe_picture/1525464/uploads_20150209T0438Z_cad56dbc530b8efabd5b65ad39c45bcc_1.165a_479x640_.jpg
# Downloaded image 59: http://grecipes.s3.amazonaws.com/recipe_picture/1525464/uploads_20150209T0438Z_cad56dbc530b8efabd5b65ad39c45bcc_1.165a_479x640_.jpg
# Downloaded image 60: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free134.jpg
# Downloaded image 61: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free44.jpg
# Downloaded image 62: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free34.jpg
# Downloaded image 63: http://grecipes.s3.amazonaws.com/recipe_picture/1506439/uploads_20140824T1845Z_cf6766bb98f57b2f981537399365eef3_DSCN1311.JPG
# Downloaded image 64: https://lh3.googleusercontent.com/blogger_img/APIUysgqD0ILJHxn0SmExxDzBIP2teEiQu2cQwKHoquKABPHqMbxVroFs25RcdDHwlM7d7P17jzva7_HcLt81w=s1600
# Downloaded image 65: https://3.bp.blogspot.com/_EosO2d3aJ3E/S1xMqm1aGoI/AAAAAAAAADc/J6GCDB0Wf8U/s1600/5.jpg
# Downloaded image 66: https://www.shutterstock.com/image-photo/mix-vegetable-masala-khichdi-khichuri-260nw-1751130722.jpg
# Downloaded image 67: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free135.jpg
# Downloaded image 68: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free138.jpg
# Downloaded image 69: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free121.jpg
# Downloaded image 70: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free123.jpg
# An error occurred while downloading image from https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free199.jpg: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Failed to download image 71: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free199.jpg
# Downloaded image 72: https://www.shutterstock.com/shutterstock/photos/566019145/display_1500/stock-photo-methi-paratha-thepla-indian-flat-bread-using-fenugreek-leaves-selective-focus-566019145.jpg
# Downloaded image 73: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free12.JPG
# Downloaded image 74: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free509.jpg
# Downloaded image 75: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free505.jpg
# Downloaded image 76: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free503.jpg
# Downloaded image 77: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free500.jpg
# Downloaded image 78: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free24.JPG
# Downloaded image 79: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free309.jpg
# Downloaded image 80: https://www.shutterstock.com/image-photo/chole-chana-masala-spicy-chickpeas-600nw-619036925.jpg
# Downloaded image 81: https://www.shutterstock.com/image-photo/punjabi-kadhi-pakoda-curry-pakora-260nw-1111862825.jpg
# Downloaded image 82: https://media.istockphoto.com/id/1249888822/photo/a-bowl-of-palak-paneer-made-of-paneer-cheese-dipped-in-mildly-spiced-spinach-gravy.jpg?s=612x612&w=0&k=20&c=OoenVkEGXIEeOtxPVn1tUNQuk1cn1PBtmJIy0nIzfDY=
# Downloaded image 83: https://somethingiscooking.com/wp-content/uploads/2017/01/MethiThepla1.jpg
# Downloaded image 84: https://smithakalluraya.com/wp-content/uploads/2017/03/VEG-JALFREZI.jpg
# Downloaded image 85: https://media.istockphoto.com/id/1170374719/photo/dal-makhani-at-dark-background.jpg?s=612x612&w=0&k=20&c=49yLaUAE2apakVk2AAiRQimZd98WtSjIQ0hzCzWsmns=
# Downloaded image 86: https://img.freepik.com/premium-photo/indian-style-suran-sabzi-jimikand-sabji-also-known-as-elephant-foot-yam-ole-stir-fried-recipe_466689-83249.jpg
# Downloaded image 87: https://indianvegrecipe.com/wp-content/uploads/2019/08/veg-handi-recipe.jpg
# Downloaded image 88: https://media.istockphoto.com/id/1146289003/photo/traditional-indian-street-food-rice-with-vegetables-close-up-on-a-plate-horizontal.jpg?s=612x612&w=0&k=20&c=Ikb_QsWs1yjKMs8izmdkAjUc2BAiBQCLOzL9uWZ7-aY=
# Downloaded image 89: https://img.freepik.com/free-photo/vertical-shot-traditional-indian-paneer-butter-masala-cheese-cottage-curry-black-surface_181624-32001.jpg
# Downloaded image 90: https://st4.depositphotos.com/19960896/23009/i/450/depositphotos_230092660-stock-photo-matar-paneer-curry-recipe-made.jpg
# Downloaded image 91: https://www.spiceupthecurry.com/wp-content/uploads/2021/08/methi-matar-malai-1-500x375.jpg
# Downloaded image 92: https://st2.depositphotos.com/49005766/46430/i/450/depositphotos_464301590-stock-photo-indian-breakfast-puri-chickpea-chana.jpg
# Downloaded image 93: https://cdn.pixabay.com/photo/2024/01/29/21/50/ai-generated-8540840_640.jpg
# Downloaded image 94: https://st3.depositphotos.com/5653638/16138/i/450/depositphotos_161386366-stock-photo-indian-street-food-vada-pav.jpg
# Downloaded image 95: https://img.freepik.com/free-photo/traditional-indian-soup-lentils-indian-dhal-spicy-curry-bowl-spices-herbs-rustic-black-wooden-table_2829-18717.jpg
# Downloaded image 96: https://st3.depositphotos.com/5653638/14980/i/450/depositphotos_149807346-stock-photo-paneer-butter-masala-or-cheese.jpg
# Downloaded image 97: https://images.pexels.com/photos/17223835/pexels-photo-17223835.jpeg?cs=srgb&dl=pexels-aditya-mara-17223835.jpg&fm=jpg
# Downloaded image 98: https://st2.depositphotos.com/5653638/11489/i/950/depositphotos_114898966-stock-photo-cooked-red-kidney-beans-curry.jpg
# Downloaded image 99: https://img.freepik.com/premium-photo/paneer-tikka-is-indian-dish-made-from-chunks-cottage-cheese-marinated-spices-grilled-tandoor_466689-76786.jpg
# Downloaded image 100: https://st3.depositphotos.com/5653638/16094/i/450/depositphotos_160945314-stock-photo-gobi-manchurian-dry-popular-street.jpg
# Downloaded image 101: https://st2.depositphotos.com/5653638/45282/i/450/depositphotos_452822374-stock-photo-malai-kofta-curry-indian-cuisine.jpg
# Downloaded image 102: https://www.masterindian.com/cdn/shop/articles/blog-aloo-gobi_1024x1024.png?v=1552147488
# Downloaded image 103: https://i0.wp.com/cookingfromheart.com/wp-content/uploads/2016/07/Pulihora-5.jpg?resize=533%2C800&ssl=1
# Downloaded image 104: https://st2.depositphotos.com/5653638/11749/i/450/depositphotos_117498296-stock-photo-indian-snacks-bhel-puri-served.jpg
# Downloaded image 105: https://www.shutterstock.com/image-photo/alu-vadi-patra-colocasia-taro-600nw-1977101867.jpg
# Downloaded image 106: https://myfoodstory.com/wp-content/uploads/2021/05/Masala-Vada-2.jpg
# Downloaded image 107: https://i0.wp.com/myspicetrunk.com/wp-content/uploads/2020/12/WhatsApp-Image-2020-12-03-at-1.07.42-PM-720x1059.jpeg?resize=720%2C1059&ssl=1
# Downloaded image 108: https://www.indianhealthyrecipes.com/wp-content/uploads/2022/03/bombay-sandwich-recipe.jpg.webp
# Downloaded image 109: https://www.shutterstock.com/image-vector/vector-illustration-sadhya-south-indian-260nw-2025224885.jpg
# Downloaded image 110: https://st2.depositphotos.com/3147737/5401/i/450/depositphotos_54019723-stock-photo-curd-rice-a-rice-mixed.jpg
# Downloaded image 111: https://st2.depositphotos.com/5653638/11521/i/950/depositphotos_115216222-stock-photo-dhokla-indian-foodgujarati-khaman-dhokla.jpg
# Downloaded image 112: https://storage.needpix.com/rsynced_images/avial-3688449_1280.jpg
# Downloaded image 113: https://upload.wikimedia.org/wikipedia/commons/0/04/Bisi_Bele_Bath_%28Bisibelebath%29.JPG
# Downloaded image 114: https://st3.depositphotos.com/5653638/15354/i/450/depositphotos_153549556-stock-photo-baigan-bharta-in-hindi-or.jpg
# Downloaded image 115: https://www.shutterstock.com/image-photo/ilish-panta-bengali-new-year-260nw-2139153519.jpg
# Downloaded image 116: https://www.shutterstock.com/image-photo/homemade-indian-spicy-eggplant-potato-600nw-664554715.jpg
# Downloaded image 117: https://st.depositphotos.com/5653638/60062/i/450/depositphotos_600626504-stock-photo-lasooni-palak-recipe-dhaba-style.jpg
# Downloaded image 118: https://st2.depositphotos.com/5653638/11508/i/450/depositphotos_115082614-stock-photo-pani-puri-or-panipuri-golgappe.jpg
# Downloaded image 119: https://www.shutterstock.com/image-photo/sev-batata-puri-papdi-chat-260nw-673732282.jpg
# Downloaded image 120: https://www.shutterstock.com/image-photo/dahi-puri-snack-popular-state-600nw-369255617.jpg
# Downloaded image 121: https://st2.depositphotos.com/5653638/11522/i/450/depositphotos_115225994-stock-photo-indian-masala-fried-bhindi-or.jpg
# Downloaded image 122: https://www.shutterstock.com/image-photo/fresh-green-mint-chutney-made-600nw-1750888160.jpg
# Downloaded image 123: https://www.shutterstock.com/image-photo/baghare-baingan-masala-eggplant-brinjal-600nw-1971619283.jpg
# Downloaded image 124: https://img.freepik.com/free-photo/pakistani-food-cloth-top-view_23-2148825097.jpg?size=626&ext=jpg&ga=GA1.1.1395880969.1709683200&semt=ais
# Downloaded image 125: https://img.freepik.com/premium-photo/indian-vegetable-pulav-biryani-made-using-basmati-rice-served-terracotta-bowl-selective-focus_466689-55615.jpg
# Downloaded image 126: https://www.shutterstock.com/image-photo/methi-malai-paneer-creamy-fenugreek-260nw-617034299.jpg
# Downloaded image 127: https://www.shutterstock.com/image-photo/patta-gobi-sabji-cabbage-sabzi-600nw-682332448.jpg
# Downloaded image 128: https://st4.depositphotos.com/19960896/31012/i/450/depositphotos_310126572-stock-photo-undhiyu-gujarati-mixed-vegetable-dish.jpg
# Downloaded image 129: https://img.freepik.com/premium-photo/punjabi-kadhi-pakoda-curry-pakora-indian-cuisine-served-bowl-karahi_466689-27014.jpg
# Downloaded image 130: https://st.depositphotos.com/5653638/60277/i/450/depositphotos_602772658-stock-photo-palak-sweet-corn-sabzi-also.jpg
# Downloaded image 131: https://www.balancenutrition.in/images/receipe-img/1436605226_large.jpg
# Downloaded image 132: https://st4.depositphotos.com/13349234/29321/i/450/depositphotos_293212704-stock-photo-potatoes-cumin-bowl.jpg
# Downloaded image 133: https://www.shutterstock.com/image-photo/paneer-bhurji-mildly-spiced-cottage-260nw-1261243846.jpg
# Downloaded image 134: https://betterfoodguru.com/wp-content/uploads/2021/03/Chana-Saag-Aloo-scaled.jpg
# Downloaded image 135: https://media.istockphoto.com/id/1186759790/photo/paneer-tikka-at-skewers-in-black-bowl-at-dark-slate-background-paneer-tikka-is-an-indian.jpg?s=612x612&w=0&k=20&c=cITToqM1KEnrixXjoLhEciqP24SxdKtW3QXykq-W5OE=
# Downloaded image 136: https://www.shutterstock.com/image-photo/healthy-nutritious-indian-comfort-food-260nw-1954017742.jpg
# Downloaded image 137: https://media.istockphoto.com/id/1225951695/photo/lachha-paratha-flatbread-on-brass-plate-isolated.jpg?s=612x612&w=0&k=20&c=L7yLXjt4lgTOWTOQ_3bqxvCLcmb7MVe2UNOgrolO9i8=
# Downloaded image 138: https://media.istockphoto.com/id/1413566368/photo/indian-food-aloo-paratha-or-indian-potato-stuffed-flatbread-served-with-butter-pickle-and.jpg?s=612x612&w=0&k=20&c=hIqRXgQTFJ4Ta_Zh_JhOc_Okjk_yJUB--uDYIjifVCc=
# Downloaded image 139: https://st.depositphotos.com/1491432/2659/i/450/depositphotos_26595855-stock-photo-sambar-idli-or-sambar-idly.jpg
# Downloaded image 140: https://www.shutterstock.com/image-photo/dahi-vada-bhalla-type-chaat-600nw-1934860373.jpg
# Downloaded image 141: https://media.istockphoto.com/id/1365859011/photo/drink-mango-lassi-in-two-glasses-on-rustic-concrete-table-with-fresh-ripe-cut-manfo-from-above.jpg?s=612x612&w=0&k=20&c=uHnr_0raQDe2sgUYHdP5GSa2raaj3ILG4m1cmFHtVJA=
# Downloaded image 142: https://www.shutterstock.com/image-photo/overhead-view-veg-kadai-curry-260nw-1935510700.jpg
# Downloaded image 143: https://media.istockphoto.com/id/515853026/photo/traditional-rasmalai-or-ras-malai-indian-dessert-bengali-sweet.jpg?s=612x612&w=0&k=20&c=LYftdDAkIa8lVyfmwt8iK-OPSQr2KCcJcYpPhbFtFBk=
# Downloaded image 144: https://www.shutterstock.com/image-photo/paneer-chilli-indo-chinese-cuisine-600nw-1876336663.jpg
# Downloaded image 145: https://img.freepik.com/free-photo/semiya-payasam-shewai-sewai-khir-seviyan-kheer-is-indian-sweet-made-with-vermicelli-milk-ghee-sugar-jaggery-raisins-nuts_466689-75455.jpg?size=626&ext=jpg&ga=GA1.1.735520172.1710288000&semt=ais
# Downloaded image 146: https://www.funfoodfrolic.com/wp-content/uploads/2020/04/Paneer-Jalfrezi.jpg
# Downloaded image 147: https://media.istockphoto.com/id/1124973765/photo/chicken-curry.jpg?s=612x612&w=0&k=20&c=YTjPGlfvT7pHiy1RX8ZcoizSdUEE9ocOAEF65H4QgJA=
# Downloaded image 148: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1161828/paneer-fried-rice_full.jpg
# Downloaded image 149: https://s3.amazonaws.com/grecipes/public/pictures/recipes/7272/korma-rice-ck-1031654-l_full.jpg
# Downloaded image 150: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1128582/img_1313[2]_full.jpg
# Downloaded image 151: https://www.shutterstock.com/image-photo/classic-fruit-nut-indian-pilau-260nw-108269183.jpg
# Downloaded image 152: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1221481/sambar_full.jpg
# Downloaded image 153: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1322952/202_large_capsicum-tofu_full.jpg
# Downloaded image 154: http://grecipes.s3.amazonaws.com/recipe_picture/1459084/full_Indian-mango-pickle-B-.jpg
# Downloaded image 155: https://s3.amazonaws.com/grecipes/public/pictures/recipes/431506/carrot_halwa_full.jpg
# Downloaded image 156: https://s3.amazonaws.com/grecipes/public/pictures/recipes/849179/dsc02656_full.jpg
# Downloaded image 157: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1074687/kjamun5_full.jpg
# Downloaded image 158: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1132342/img_20120129_110819_full.jpg
# Downloaded image 159: http://grecipes.s3.amazonaws.com/recipe_picture/1442514/full_dhoodhpeda.jpg
# Downloaded image 160: https://www.shutterstock.com/image-photo/bharwa-karela-masala-fry-stuffed-260nw-2101741081.jpg
# Downloaded image 161: https://www.shutterstock.com/image-photo/rice-mixed-vegetables-260nw-361713575.jpg
# Downloaded image 162: https://www.shutterstock.com/shutterstock/videos/5965445/thumb/1.jpg?ip=x480
# Downloaded image 163: https://media.istockphoto.com/id/1209898811/photo/chapati-wrap-with-cheese-vegetarian-food.jpg?s=612x612&w=0&k=20&c=nSbQOQrOq4W2VDYlazvsX9BERrqPekAM5KIEMf0kwCU=
# Downloaded image 164: https://www.shutterstock.com/image-photo/stir-fried-taro-roots-arbi-600nw-1858324504.jpg
# Downloaded image 165: https://www.shutterstock.com/image-photo/paneer-bhurji-gravy-served-bowl-260nw-1597943206.jpg
# Downloaded image 166: https://www.shutterstock.com/image-photo/green-peas-stuffed-flat-bread-260nw-783950896.jpg
# Downloaded image 167: https://www.shutterstock.com/image-photo/healthy-food-oats-chilla-veggies-260nw-2256544083.jpg
# Downloaded image 168: https://www.shutterstock.com/image-photo/dum-handi-gosht-pilaf-prepared-260nw-1995758066.jpg
# Downloaded image 169: https://www.shutterstock.com/image-photo/malabar-fresh-homecooked-parotta-handmade-260nw-1857393661.jpg
# Downloaded image 170: https://www.shutterstock.com/image-photo/shakkar-pare-shakkarpare-shankar-pale-260nw-2221241253.jpg
# Downloaded image 171: https://www.shutterstock.com/image-photo/paneer-korma-kurma-quorma-popular-260nw-1595283805.jpg
# Downloaded image 172: https://www.shutterstock.com/image-photo/pakora-pakoda-traditional-popular-indian-260nw-1011403585.jpg
# Downloaded image 173: https://www.shutterstock.com/image-photo/cumin-rice-jeera-popular-indian-260nw-1785410987.jpg
# Downloaded image 174: https://www.shutterstock.com/image-photo/veg-poha-cutlet-flattened-rice-260nw-1574859061.jpg
# Downloaded image 175: https://www.shutterstock.com/image-photo/top-view-indian-aloo-palak-600w-1874767843.jpg
# Downloaded image 176: https://www.shutterstock.com/image-photo/daikon-radish-mooli-muli-paratha-260nw-523414645.jpg
# Downloaded image 177: https://www.shutterstock.com/image-photo/khajur-barfi-khajoor-dry-fruits-260nw-2261200797.jpg
# Downloaded image 178: https://www.shutterstock.com/image-photo/palak-paneer-curry-made-spinach-260nw-620912093.jpg
# Downloaded image 179: https://www.shutterstock.com/image-photo/roasted-phool-makhana-crispy-masala-260nw-2067202442.jpg
# Downloaded image 180: https://www.shutterstock.com/image-photo/namkeen-kasuri-methi-masala-mathri-260nw-2269061467.jpg
# Downloaded image 181: https://www.shutterstock.com/image-photo/sweet-dink-laddu-known-dinkache-260nw-1600091485.jpg
# Downloaded image 182: https://www.shutterstock.com/image-photo/indian-phool-gobi-shimla-mirch-260nw-2443419187.jpg
# Downloaded image 183: https://www.shutterstock.com/image-photo/bhindi-masala-ladies-finger-fry-600nw-2148588109.jpg
# Downloaded image 184: https://www.shutterstock.com/shutterstock/photos/1782726167/display_1500/stock-photo-aluwadi-paatra-maharashtrian-and-gujrati-snack-recipe-made-using-colocasia-leaves-1782726167.jpg
# Downloaded image 185: https://media.istockphoto.com/id/1146289003/photo/traditional-indian-street-food-rice-with-vegetables-close-up-on-a-plate-horizontal.jpg?s=170667a&w=is&k=20&c=Fsf_b9GAFNNuaRXbasuMGt3ziMBfIRzb-WW6nwlIsuQ=
# Downloaded image 186: https://www.shutterstock.com/image-photo/gulab-jamuns-indian-dessert-topped-600nw-295395848.jpg
# Downloaded image 187: https://www.shutterstock.com/image-photo/dahi-vada-bhalla-type-chaat-600nw-1934860373.jpg
# Downloaded image 188: https://www.shutterstock.com/image-photo/tasty-spicy-chana-pulao-pulav-600nw-1899309709.jpg
# Downloaded image 189: https://www.shutterstock.com/image-photo/aloo-mutter-matar-aalu-dry-600nw-1899776431.jpg
# Downloaded image 190: https://www.shutterstock.com/image-photo/homemade-roti-chapati-flatbread-on-260nw-1902815578.jpg
# Downloaded image 191: https://www.shutterstock.com/shutterstock/photos/2095156876/display_1500/stock-photo-aloo-mutter-is-a-punjabi-dish-from-the-indian-subcontinent-which-is-made-from-potatoes-and-peas-in-2095156876.jpg
# Downloaded image 192: https://www.shutterstock.com/image-photo/palak-paneer-curry-made-spinach-260nw-620862155.jpg
# Downloaded image 193: https://www.shutterstock.com/image-photo/matar-paneer-curry-recipe-made-260nw-1250565787.jpg
# Downloaded image 194: https://www.shutterstock.com/image-photo/indian-traditional-chats-kachori-recipe-260nw-1508649266.jpg
# Downloaded image 195: https://www.shutterstock.com/image-photo/cooked-bitter-melongourd-karela-sabzi-260nw-1264583032.jpg
# Downloaded image 196: https://www.shutterstock.com/image-photo/aam-ka-murabba-methamba-known-260nw-641289094.jpg
# Downloaded image 197: https://www.shutterstock.com/image-photo/paneer-pulao-fragrant-delicious-mildly-260nw-2082103693.jpg
# Downloaded image 198: https://www.shutterstock.com/image-photo/indian-veg-chapati-wrap-kathi-260nw-1147885403.jpg
# Downloaded image 199: https://www.shutterstock.com/image-photo/mix-vegetable-masala-khichdi-khichuri-600nw-1751130722.jpg
# Downloaded image 200: https://www.shutterstock.com/image-photo/cooked-tikka-tray-mushroom-vigatable-260nw-2403074883.jpg
# Downloaded image 201: https://www.shutterstock.com/image-photo/chole-aloo-paratha-alu-parantha-600nw-1950454744.jpg
# Downloaded image 202: https://www.shutterstock.com/image-photo/daikonradish-mooli-stuffed-paratha-served-260nw-523414639.jpg
# Downloaded image 203: https://www.shutterstock.com/shutterstock/photos/1520877488/display_1500/stock-photo-the-indian-traditional-food-chhole-kulchha-or-kulcha-black-olive-jalapeno-kultcha-amritsari-1520877488.jpg
# Downloaded image 204: https://www.shutterstock.com/image-photo/methi-dal-healthy-flavorful-dish-260nw-2418686343.jpg
# Downloaded image 205: https://www.shutterstock.com/image-photo/arabic-cuisine-egyptian-traditional-green-260nw-2305288599.jpg
# Downloaded image 206: https://www.shutterstock.com/shutterstock/photos/1933814894/display_1500/stock-photo--suji-cheela-chilla-with-spicy-home-style-potatoes-vrat-ki-thali-selective-focus-1933814894.jpg
# Downloaded image 207: https://www.shutterstock.com/image-photo/indian-baby-corn-masalacurry-prepared-600nw-771356068.jpg
# Downloaded image 208: https://www.shutterstock.com/image-photo/fresh-mango-lassi-glasses-on-260nw-2312893983.jpg
# Downloaded image 209: https://www.shutterstock.com/image-photo/famous-indian-cuisines-aloo-paratha-260nw-1206944158.jpg
# Downloaded image 210: https://www.shutterstock.com/image-photo/paksitaniindian-style-dough-bread-filled-600nw-1026682657.jpg
# Downloaded image 211: https://www.shutterstock.com/shutterstock/photos/1037621233/display_1500/stock-photo-paneer-khurchan-stir-fried-indian-cottage-cheese-with-bell-pepper-and-tomatoes-with-indian-spices-1037621233.jpg
# Downloaded image 212: https://www.shutterstock.com/image-photo/boondi-raita-north-indian-side-600nw-2041601327.jpg
# Downloaded image 213: https://www.shutterstock.com/image-photo/semiya-payasam-shewai-sewai-khir-260nw-2087561293.jpg
# Downloaded image 214: https://www.shutterstock.com/image-photo/indian-sweet-dessert-traditional-home-600nw-674011279.jpg
# Downloaded image 215: https://www.shutterstock.com/image-photo/kerala-paratha-type-indian-bread-600nw-788046232.jpg
# Downloaded image 216: https://www.shutterstock.com/image-photo/mughlai-chicken-pulao-tasty-rice-260nw-2394531455.jpg
# Downloaded image 217: https://www.shutterstock.com/image-photo/achari-paneer-tikka-spicy-grilled-260nw-2331213315.jpg
# Downloaded image 218: https://media.istockphoto.com/id/1072893062/photo/beetroot-halwa-garnished-with-pistachio-served-in-a-bowl-selective-focus.jpg?s=612x612&w=0&k=20&c=aBtTxPRC2tjuarBcEF-jepmfQK-bNY7EKnEJApNyayk=
# Downloaded image 219: https://www.shutterstock.com/image-photo/closeup-view-pindi-choleamritsari-chole-260nw-2208000689.jpg
# Downloaded image 220: https://www.shutterstock.com/image-photo/amritsari-paneer-tikka-made-using-260nw-1597285756.jpg
# Downloaded image 221: https://www.shutterstock.com/image-photo/peanut-chikki-balls-brittle-laddu-260nw-2402390839.jpg
# Downloaded image 222: https://www.shutterstock.com/image-photo/crispy-fried-chicken-pork-tonkatsu-260nw-2119781660.jpg
# Downloaded image 223: https://www.shutterstock.com/image-photo/rajma-razma-popular-north-indian-260nw-620241107.jpg
# Downloaded image 224: https://www.shutterstock.com/image-photo/fried-onion-pakora-pyaj-pakoda-260nw-1773809372.jpg
# Downloaded image 225: https://www.shutterstock.com/image-photo/chana-dal-khichdi-famous-delicious-260nw-645802459.jpg
# Downloaded image 226: https://static.toiimg.com/thumb/62775347.cms?imgsize=171877&width=800&height=800
# Downloaded image 227: https://www.shutterstock.com/image-photo/masala-chaas-served-papad-600nw-1035426676.jpg
# Downloaded image 228: https://www.shutterstock.com/image-photo/closeup-creamy-rice-kheerkhir-garnished-260nw-1982444912.jpg
# Downloaded image 229: https://www.shutterstock.com/image-photo/tandoori-aloo-roasted-potatoes-indian-260nw-1390660430.jpg
# Downloaded image 230: https://www.shutterstock.com/image-photo/masala-idli-idly-chilli-coconut-260nw-2089848553.jpg
# Downloaded image 231: https://www.shutterstock.com/image-photo/paneer-stuffed-besan-chilla-cheela-600nw-2203630003.jpg
# Downloaded image 232: https://www.shutterstock.com/image-photo/traditional-indian-fasting-food-recipe-260nw-1932957770.jpg
# Downloaded image 233: https://www.shutterstock.com/image-photo/kada-prasad-atta-north-indian-260nw-1951257394.jpg
# Downloaded image 234: https://www.shutterstock.com/image-photo/seekh-kabab-made-minced-chicken-260nw-2108952152.jpg
# Downloaded image 235: https://www.shutterstock.com/image-photo/besan-ladoo-badam-kaju-600nw-1097047979.jpg
# Downloaded image 236: https://www.shutterstock.com/image-photo/gur-ki-kheer-called-jaggery-260nw-2261200795.jpg
# Downloaded image 237: https://www.shutterstock.com/shutterstock/photos/2070426818/display_1500/stock-photo-choley-chole-masala-or-chana-an-indian-food-made-of-chickpeas-tomatoes-and-cumin-served-with-2070426818.jpg
# Downloaded image 238: https://www.shutterstock.com/image-photo/makki-ki-roti-sarson-ka-260nw-774849826.jpg
# Downloaded image 239: https://www.shutterstock.com/image-photo/chole-aloo-tikki-chaat-simple-600nw-2184141605.jpg
# Downloaded image 240: https://www.shutterstock.com/image-photo/indian-baby-corn-masalacurry-prepared-600nw-771356464.jpg
# Downloaded image 241: https://www.shutterstock.com/image-photo/gobi-pakora-phoolgobi-pakoda-made-260nw-1587548371.jpg
# Downloaded image 242: https://www.shutterstock.com/image-photo/indian-fasting-cuisine-upwas-items-260nw-1931927969.jpg
# Downloaded image 243: https://www.shutterstock.com/image-photo/closeup-homemade-beetroot-poori-fried-260nw-2401092157.jpg
# Downloaded image 244: https://www.shutterstock.com/image-photo/hyderabad-famous-ramazan-special-sweet-260nw-2157642553.jpg
# Downloaded image 245: https://www.shutterstock.com/image-photo/aloo-sandwich-potato-260nw-1717205344.jpg
# Downloaded image 246: https://www.shutterstock.com/image-photo/yogurt-pineapple-ananas-raita-served-260nw-590939285.jpg
# Downloaded image 247: https://www.shutterstock.com/image-photo/traditional-indian-spicy-crunchy-aloo-600nw-1430062514.jpg
# Downloaded image 248: https://media.istockphoto.com/id/506625143/photo/kaju-katli-3.jpg?s=612x612&w=0&k=20&c=q4p0oAhCLNdEeKm8kArRcX7jKgJSmB_HaRzD5_nV7Lg=
# Downloaded image 249: https://www.indianhealthyrecipes.com/wp-content/uploads/2022/02/kadai-mushroom.jpg
# Downloaded image 250: https://www.alcofoods.com/cdn/shop/articles/paneer_labbadar_600x.jpg?v=1683722725
# Downloaded image 251: https://img.freepik.com/free-photo/warm-tomato-soup-serve-bowl_1150-42626.jpg
# Downloaded image 252: https://cdn1.foodviva.com/static-content/food-images/lunch-recipes/lauki-kofta-curry/lauki-kofta-curry.jpg
# Downloaded image 253: https://www.shutterstock.com/image-photo/chole-bhature-north-indian-food-600nw-2238261205.jpg
# Downloaded image 254: https://www.shutterstock.com/image-photo/traditional-ball-shaped-indian-mithai-600nw-2258232827.jpg
# Downloaded image 255: https://thumbs.dreamstime.com/b/indian-paneer-masala-tawa-tikka-vegetarian-curry-dish-side-food-cuisine-bowl-top-down-directly-above-photo-147143557.jpg
# Downloaded image 256: https://img.freepik.com/free-photo/vertical-shot-traditional-indian-paneer-butter-masala-cheese-cottage-curry-black-surface_181624-32001.jpg
# Downloaded image 257: https://www.shutterstock.com/image-photo/chana-dal-organic-tur-split-600nw-1618918879.jpg
# Downloaded image 258: https://media.istockphoto.com/id/1692099288/photo/punjabi-food-sarson-ka-saag-in-bowl-at-food-table.jpg?s=612x612&w=0&k=20&c=lBuOH3O4N52Q8E9viy9kBvN0yVLNfGHLjtKT6I6upJQ=
# Downloaded image 259: https://media.istockphoto.com/id/537532787/photo/rice-with-mung-bean-and-spices-close-up-top-view.jpg?s=612x612&w=0&k=20&c=rfC7JX6fMnaDyBz7Ls9v222ZikKeySxE4W-uPnSPEHw=
# Downloaded image 260: https://www.shutterstock.com/image-photo/moong-dal-halwa-classic-indian-600nw-1778577107.jpg
# Downloaded image 261: https://media.istockphoto.com/id/163064596/photo/gulab-jamun.jpg?s=612x612&w=0&k=20&c=JvJ4AAs-N5pRzzRmVg1lG0talC3QoUt0ZGiO1NKz-kQ=
# Downloaded image 262: https://www.shutterstock.com/image-photo/bharwa-masala-bhindi-stuffed-indian-260nw-1792674436.jpg
# Downloaded image 263: https://media.istockphoto.com/id/1256978725/photo/moong-dal-halwa-or-mung-daal-halva-is-an-indian-sweet-dessert-recipe-garnished-with-dry-fruits.jpg?s=612x612&w=0&k=20&c=3C3TzD6l28y9C_AlobiVHPAsIaNR6xE6rRIGITFepuA=
# Downloaded image 264: https://thumbs.dreamstime.com/b/malai-kofta-curry-black-bowl-dark-slate-background-indian-cuisine-dish-food-potato-paneer-cheese-deep-fried-179415022.jpg
# Downloaded image 265: https://www.shutterstock.com/image-photo/malai-achari-paneer-gravy-made-600nw-1263157405.jpg
# Downloaded image 266: https://media.istockphoto.com/id/1143530040/photo/indian-naan-bread-with-garlic-butter-on-wooden-table.jpg?s=612x612&w=0&k=20&c=71SgbJtnfiHUiud1oGxnhiZsx5nuivWwZt8DlIk8hi0=
# Downloaded image 267: https://media.istockphoto.com/id/1316583859/photo/mango-pickle-or-aam-ka-aachar-or-achar-in-a-bowl-on-wooden-background-theme-with-raw-mangos.jpg?s=612x612&w=0&k=20&c=dQqg5cBILEP-7WJB5LYLYdopSoqZ1ebc9cxXif80DJk=
# Downloaded image 268: https://thumbs.dreamstime.com/b/indian-desert-kheer-made-rice-milk-saffron-nuts-32836407.jpg
# Downloaded image 269: https://www.alcofoods.com/cdn/shop/articles/244e8c208fba8f3f923c9edf1c8a8a00.jpg?v=1684501141
# Downloaded image 270: https://media.istockphoto.com/id/657076158/photo/rajwari-or-rajwadi-sweet-kesar-badam-pista-kulfi-or-ice-cream-candy.jpg?s=612x612&w=0&k=20&c=p0eXjjHOxAawVv32t9a5WOWBEGT-XNMXxbiwtWg1Qs4=
# Downloaded image 271: https://media.istockphoto.com/id/1024585168/photo/paneer-butter-masala-also-known-as-panir-makhani-or-makhanwala-served-in-a-ceramic-or-wooden.jpg?s=612x612&w=0&k=20&c=DbA7ucx0xpS18zO1sFIaAmm41xKF-iIlKxOjbgFZJ1o=
# Downloaded image 272: https://www.shutterstock.com/image-photo/paneer-pasanda-famous-indian-dish-260nw-1876374943.jpg
# Downloaded image 273: https://media.istockphoto.com/id/1292629539/photo/paneer-tikka-masala-is-a-famous-indian-dish-served-over-a-rustic-wooden-background-selective.jpg?s=612x612&w=0&k=20&c=GCvoJ3lBcvvRJmeENmSpa_7rLkh_1OKPaM6gKNYqUGM=
# Downloaded image 274: https://www.shutterstock.com/image-photo/maa-ki-dal-flavoured-tangy-600nw-1274129455.jpg
# Downloaded image 275: https://www.shutterstock.com/image-photo/kashmiri-dum-aloo-spicy-potato-600nw-725768287.jpg
# Downloaded image 276: https://media.istockphoto.com/id/174961905/photo/gobi-aloo-indian-curry-dish.jpg?s=612x612&w=0&k=20&c=Ztm0QBsc4GFm_5yD5v0Dfy5j-Odm1VuMBVhFOEQoO8I=
# Downloaded image 277: https://thumbs.dreamstime.com/b/indian-snack-food-matar-kachori-looks-amazing-seems-very-tasty-lovely-brown-color-indian-snack-food-matar-kachori-197794744.jpg
# Downloaded image 278: https://media.istockphoto.com/id/465049010/photo/stuffed-yellow-and-red-peppers.jpg?s=612x612&w=0&k=20&c=14m9BnzQ7qWJ6byxt6je6xbnF9tlKiKSX6gQqvfeV4Y=
# Downloaded image 279: https://www.shutterstock.com/image-photo/dal-bukhara-rich-creamy-slow-600nw-1639566229.jpg
# Downloaded image 280: https://www.shutterstock.com/shutterstock/photos/263027990/display_1500/stock-photo-amritsari-aloo-kulcha-with-choley-or-stuffed-potato-bread-white-chickpeas-263027990.jpg
# Downloaded image 281: https://www.indianhealthyrecipes.com/wp-content/uploads/2022/07/hara-bhara-kabab.jpg
# Downloaded image 282: https://www.shutterstock.com/image-photo/motichoor-laddu-addu-260nw-2352174411.jpg
# Downloaded image 283: https://media.istockphoto.com/id/452092395/photo/semolina.jpg?s=612x612&w=0&k=20&c=Z6e1Os5aaGVrNIvLRQdH4bxgYEwiTpmhWSPeLW0HR9o=
# Downloaded image 284: https://media.istockphoto.com/id/1370764504/photo/tom-yum-soup-thai-soup-with-prawns-and-rice-noodles-on-black-wooden-table.jpg?s=612x612&w=0&k=20&c=Tws6NmTgJzGhCRuWtHtW5xlt49XYKmzg5TETrcoXGOM=
# Downloaded image 285: https://www.shutterstock.com/image-photo/veg-kolhapuri-black-bowl-on-260nw-1827501401.jpg
# Downloaded image 286: https://www.shutterstock.com/image-photo/indian-masala-fried-okra-bhindi-600nw-328654589.jpg
# Downloaded image 287: https://thumbs.dreamstime.com/b/kalakand-closeup-delicious-fresh-unique-mithai-most-famous-pakistani-indian-peoples-34186313.jpg
# Downloaded image 288: https://media.istockphoto.com/id/1197995878/photo/vegetarian-paneer-biryani-or-panir-pulav-popular-indian-food.jpg?s=1024x1024&w=is&k=20&c=7dK-jnLgVEaGbTBRtwaKiu4lDt9gIfVxbzYhyv-TeFY=
# Downloaded image 289: https://media.istockphoto.com/id/1087995822/photo/indian-food-aloo-curry-masala-potato-cooked-with-spices-and-herbs-in-a-tomato-curry-served-in.jpg?s=612x612&w=0&k=20&c=gaN_zVy3HxS_XJ3Ap9bnQJ0pDtZyteMgcIdtV3bsFek=
# Downloaded image 290: https://media.istockphoto.com/id/1130228942/photo/indian-dal-traditional-indian-soup-lentils-indian-dhal-spicy-curry-in-bowl-spices-herbs.jpg?s=612x612&w=0&k=20&c=ciPGZR4hkLeUL-nRxY4iAh539zYLgUkNz82GG_nJG5A=
# Downloaded image 291: https://www.shutterstock.com/image-photo/semiya-payasam-shewai-sewai-khir-260nw-2087561293.jpg
# Downloaded image 292: https://www.shutterstock.com/image-photo/dahi-bhindi-okra-yogurt-gravy-600nw-1588140682.jpg
# Downloaded image 293: https://thumbs.dreamstime.com/b/sliced-bread-upma-isolated-white-background-india-sliced-bread-upma-isolated-white-background-184709963.jpg
# Downloaded image 294: https://thumbs.dreamstime.com/b/matar-mushroom-curry-onion-garlic-174400448.jpg
# Downloaded image 295: https://www.shutterstock.com/image-photo/sweet-rabdi-lachha-rabri-basundi-260nw-1230247282.jpg
# Downloaded image 296: https://www.shutterstock.com/image-photo/green-peas-curry-matar-masala-260nw-1250569741.jpg
# Downloaded image 297: https://www.shutterstock.com/image-photo/aloo-palak-sabzi-spinach-potatoes-600nw-1294326967.jpg
# Downloaded image 298: https://media.istockphoto.com/id/1331733977/photo/gobi-paratha-or-cauliflower-paratha-is-a-type-of-paratha-or-parantha-or-flatbread-that-is.jpg?s=612x612&w=0&k=20&c=OCXwayRuiVDQW8_2II-cR6FaUfKpg2eRaO_GhB4Jm_A=
# Downloaded image 299: https://st.depositphotos.com/5653638/60062/i/450/depositphotos_600626732-stock-photo-lasooni-palak-recipe-dhaba-style.jpg
# Downloaded image 300: https://www.shutterstock.com/image-photo/pumpkin-kaddu-ki-sabzi-served-260nw-695950867.jpg
# Downloaded image 301: https://www.shutterstock.com/image-photo/dal-makhani-makhni-popular-dish-260nw-1204892983.jpg
# Downloaded image 302: https://st4.depositphotos.com/24035432/25204/i/450/depositphotos_252049976-stock-photo-maalpua-an-indian-sweet-snack.jpg
# Downloaded image 303: https://ministryofcurry.com/wp-content/uploads/2022/04/Aloo-Gobi-4.jpg
# Downloaded image 304: https://media.istockphoto.com/id/1087434658/photo/karela-achar-bitter-gourd-pickle-popular-indian-recipe.jpg?s=612x612&w=0&k=20&c=J2lx0n-UItFF2g6loyWkUEKyppoRpDUCapah5nyM1jI=
# Downloaded image 305: https://www.shutterstock.com/image-photo/kulcha-stuffed-indian-bread-vegetable-600nw-1021207453.jpg
# Downloaded image 306: https://thumbs.dreamstime.com/b/kala-chana-curry-delicious-masala-served-dish-191176665.jpg
# Downloaded image 307: https://media.istockphoto.com/id/1079019508/photo/cashew-curry-indian-kaju-masala-served-in-a-bowl-or-pan-selective-focus.jpg?s=612x612&w=0&k=20&c=dvnO83WfdKcaQd2z-r3fSeYRnsI5KIQ-dRp_Uc3ABkE=
# Downloaded image 308: https://www.shutterstock.com/image-photo/indian-traditional-cuisine-chapati-phooli-600nw-1225846345.jpg
# Downloaded image 309: https://www.shutterstock.com/image-photo/indian-mushroom-masala-curry-naan-260nw-771724963.jpg
# Downloaded image 310: https://www.shutterstock.com/image-photo/paneer-payasam-cottage-cheese-kheer-260nw-2052516326.jpg
# Downloaded image 311: https://www.shutterstock.com/image-photo/sandwich-bread-pakora-pakoda-triangle-600nw-783713575.jpg
# Downloaded image 312: https://www.sharmispassions.com/wp-content/uploads/2013/11/SweetCornPulao1-500x375.jpg
# Downloaded image 313: https://www.shutterstock.com/image-photo/aloo-gobi-masala-curry-chapati-600nw-2089363450.jpg
# Downloaded image 314: https://www.shutterstock.com/image-photo/lassi-drink-indian-traditional-clay-260nw-1766218529.jpg
# Downloaded image 315: https://media.istockphoto.com/id/1358749870/photo/indian-cuisine-aloo-methi-sabji-or-fenugreek-potato-sabji-served-in-a-karahi.jpg?s=612x612&w=0&k=20&c=yvUOXv4BGjCzjNVIDuFxpS1cHjw9cSCYkwl0i3JTz8g=
# Downloaded image 316: https://www.shutterstock.com/image-photo/bread-halwa-called-halva-sheera-260nw-2214958095.jpg
# Downloaded image 317: https://media.istockphoto.com/id/1204866803/photo/indian-potato-patties-aloo-tikki-served-with-yogurt-close-up-in-a-dish-horizontal-top-view.jpg?s=612x612&w=0&k=20&c=G7VRISuqTrUi_1D6O_EtjH2b1VH6H2yR-D9HKD7ro9s=
# Downloaded image 318: https://thumbs.dreamstime.com/b/spicy-fried-potaoes-roasted-cumin-seeds-24939086.jpg
# Downloaded image 319: https://www.shutterstock.com/image-photo/traditional-rice-porridge-payaru-kanji-260nw-427647223.jpg
# Downloaded image 320: https://www.shutterstock.com/image-photo/tahri-tehri-tehiri-tahari-indian-260nw-2184751631.jpg
# Downloaded image 321: https://thumbs.dreamstime.com/z/mathi-sweet-mathari-til-atta-mathri-mathi-sweet-mathari-til-atta-mathri-indian-snack-299110098.jpg
# Downloaded image 322: https://www.shutterstock.com/image-photo/perfect-crispy-jalebi-recipe-how-600nw-1579194580.jpg
# Downloaded image 323: https://media.istockphoto.com/id/980049442/photo/stuffed-paneer-paratha-with-melting-butter-served-with-fresh-cottage-cheese-cubes-and-tomato.jpg?s=612x612&w=0&k=20&c=44IJMPhvdInR4r3JDhHoLsQ3AtF49tnHvnA2eUDz8CQ=
# Downloaded image 324: https://www.shutterstock.com/image-photo/puri-bhaji-poori-masalaaloo-sabzialoo-600nw-1397230991.jpg
# Downloaded image 325: https://media.istockphoto.com/id/1158833399/photo/chilla-or-besan-cheela-or-veg-omelette.jpg?s=612x612&w=0&k=20&c=w_5zMagsjGAhc20Tvnwzpy24TD3sjJWqC7ImrwgnG6w=
# Downloaded image 326: https://www.shutterstock.com/image-photo/mint-onion-paratha-butter-260nw-649041898.jpg
# Downloaded image 327: https://www.shutterstock.com/image-photo/fruit-tangy-by-combining-chilled-600nw-1898179651.jpg
# Downloaded image 328: https://www.shutterstock.com/image-photo/dal-makhani-indian-black-lentil-600nw-2240392383.jpg
# Downloaded image 329: https://www.spiceupthecurry.com/wp-content/uploads/2015/10/carrot-burfi-recipe-9.jpg
# Downloaded image 330: https://thumbs.dreamstime.com/b/veg-burger-aloo-tikki-white-sauce-indian-restaurant-187367162.jpg
# Downloaded image 331: https://www.shutterstock.com/shutterstock/photos/2166625903/display_1500/stock-photo-loki-halwa-or-lauki-halwa-2166625903.jpg
# Downloaded image 332: https://www.shutterstock.com/image-photo/pulao-peas-matar-rice-vegetables-260nw-2379983785.jpg
# Downloaded image 333: https://www.shutterstock.com/image-photo/falooda-faluda-popular-indian-dessert-260nw-1407220004.jpg
# Downloaded image 334: https://www.shutterstock.com/image-photo/namak-para-indian-snack-which-260nw-1417527896.jpg
# Downloaded image 335: https://www.shutterstock.com/image-photo/methi-malai-paneer-creamy-fenugreek-260nw-617034299.jpg
# Downloaded image 336: https://media.istockphoto.com/id/1278584350/photo/veg-kolhapuri-in-black-bowl-on-dark-slate-table-top-indian-vegetable-curry-dish-vegetarian.jpg?s=612x612&w=0&k=20&c=J8J66FYYLs9tupC46-_de1qnASgaEsQn-yk3yW86DJ4=
# Downloaded image 337: https://media.istockphoto.com/id/1250618172/photo/tangy-tamarind-puree-or-imli-paste.jpg?s=612x612&w=0&k=20&c=bml1x7NOgYbp0R7giVbAF4D-s_bneqmkNadkkql-08c=
# Downloaded image 338: https://thumbs.dreamstime.com/b/mango-kulfi-also-spelled-khulfi-qulfi-popular-frozen-dairy-dessert-indian-subcontinent-often-described-as-88813688.jpg
# Downloaded image 339: https://www.shutterstock.com/image-photo/palak-paratha-indian-flat-breads-260nw-1737184049.jpg
# Downloaded image 340: https://media.istockphoto.com/id/1220350725/photo/indian-salted-lemonade-aam-panna.jpg?s=612x612&w=0&k=20&c=viUP0Zb1yyEjJiWG7nKj26n805C0GRoV83fKPO_cYY4=
# Downloaded image 341: https://www.shutterstock.com/image-photo/indian-famous-sweet-food-kala-260nw-433128808.jpg
# Downloaded image 342: https://thumbs.dreamstime.com/b/lauki-chana-dal-north-indian-dish-84414971.jpg
# Downloaded image 343: https://media.istockphoto.com/id/520961869/photo/vegetable-paratha-1.jpg?s=612x612&w=0&k=20&c=t4h_E3Gm8631Dng6SkXWLxPFsG-65BtKxPEOSwWx0NA=
# Downloaded image 344: https://media.istockphoto.com/id/1251472221/photo/lotus-seeds-peas-curry-or-phool-makhana-masala-sabzi.jpg?s=612x612&w=0&k=20&c=s1GhuewzGMZZM5_RU3ltPKR7X-zcz4nj9t0YqoVvaPY=
# Downloaded image 345: https://www.shutterstock.com/image-photo/khoya13-260nw-128129657.jpg
# Downloaded image 346: https://thumbs.dreamstime.com/b/delicious-soan-papadi-served-white-bowl-indian-sweet-snack-halwa-rustic-background-131634289.jpg
# Downloaded image 347: https://www.funfoodfrolic.com/wp-content/uploads/2020/09/Gobi-Tikka-Blog-Thumbnail.jpg
# Downloaded image 348: https://www.shutterstock.com/shutterstock/photos/1263154453/display_1500/stock-photo-paneer-do-pyaza-is-a-popular-punjabi-vegetarian-recipe-using-cubes-of-cottage-cheese-with-lots-of-1263154453.jpg
# Downloaded image 349: https://www.shutterstock.com/image-photo/dahi-wale-aloo-curd-potato-600nw-2134244645.jpg
# Downloaded image 350: https://www.shutterstock.com/image-photo/bajra-jowar-roti-indian-bread-600nw-762078415.jpg
# Downloaded image 351: https://media.istockphoto.com/id/515853026/photo/traditional-rasmalai-or-ras-malai-indian-dessert-bengali-sweet.jpg?s=612x612&w=0&k=20&c=LYftdDAkIa8lVyfmwt8iK-OPSQr2KCcJcYpPhbFtFBk=
# Downloaded image 352: https://www.shutterstock.com/image-photo/bharwa-masala-bhindi-stuffed-indian-600nw-1792674442.jpg
# Downloaded image 353: https://i0.wp.com/vegecravings.com/wp-content/uploads/2018/02/Aloo-Beans-Recipe-Step-By-Step-Instructions.jpg?fit=2044%2C1836&quality=65&strip=all&ssl=1
# Downloaded image 354: https://www.shutterstock.com/image-photo/palak-corn-indian-main-course-600nw-1779972806.jpg
# Downloaded image 355: https://www.shutterstock.com/image-photo/shahi-tukda-double-ka-meetha-260nw-521269165.jpg
# ...
# Downloaded image 1039: https://www.shutterstock.com/image-photo/extreme-close-shrimp-crab-cocktail-600nw-283144847.jpg
# Downloaded image 1040: https://www.shutterstock.com/image-photo/smoked-salmon-lemon-dill-top-260nw-1576382782.jpg
# Downloaded image 1041: https://www.eatingwell.com/thmb/BarPqAM5i4yw9lod0L23bUoeKCY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/shrimp-fish-stew-hero-06-729f3e269bb84991a850864cf0b2573d.jpg
# Downloaded image 1042: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRn5PCWr-NYJTwcdlwDw6KC9MpcZjVRbmkUBTgO2jEjLw&s
# Downloaded image 1043: https://www.onceuponachef.com/images/2023/10/Schnitzel-Hero-1.jpg
# Downloaded image 1044: https://www.shutterstock.com/shutterstock/photos/275750720/display_1500/stock-photo-assorted-fish-kebabs-king-big-shrimp-prawn-skewers-wood-board-top-view-isolated-275750720.jpg
# Downloaded image 1045: https://www.allrecipes.com/thmb/JbOeXhnkcEmDNoi2ZlJPk-VL1A4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/6569367-d845cae4ccd64f498a5a6c7fc2adcb88.jpg
# Downloaded image 1046: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTi0WZxBcgFCZpKJBsBL2NJNU2YgLUvZG3Kq7aJ8kGNLg&s
# Downloaded image 1047: https://www.allrecipes.com/thmb/3es9jI2W0huSN_rBCbKgBN-XWjA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/221361-traditional-sauerbraten-beauty-2x1-BP-2927-61e6ad8fae53472ca528c22383113d42.jpg
# Downloaded image 1048: https://staticcookist.akamaized.net/wp-content/uploads/sites/22/2022/09/Currywurst-12-1200x675.jpg
# Downloaded image 1049: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgDWuyJlUfCLkgWBvHH1TbwWOdzSpQumUNs624OSKMZg&s
# Downloaded image 1050: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6wRrKfpcqkgoIyW7mszM7ph18uvUoN94RRptUBJI0eQ&s
# Downloaded image 1051: https://img.taste.com.au/rIljzoV7/taste/2022/09/sri-lankan-beef-kottu-roti-181296-1.jpg
# Downloaded image 1052: https://www.allrecipes.com/thmb/nKyhKSQNe3cWKPlDnV3LvyYgrDI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/609167-fcde3d214a3b4ee49eaf679ad46198d1.jpg
# Downloaded image 1053: https://hungrylankan.com/wp-content/uploads/2020/07/20200705_125604_compress10.jpg
# Downloaded image 1054: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpDpt2zlF5OtkinCLjKj24SAnq48w0talSWMqQIug3vQ&s
# Downloaded image 1055: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHgKZKsUX1zkXxZCSMFu4NE8i_8gJTOje9zdQA5lWOuA&s
# Downloaded image 1056: https://www.simplyrecipes.com/thmb/2GMHFcWEHZGOYbT4eoVCAu2uwsw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2018__07__Seafood-Paella-LEAD-VERTICAL-fc5f1e71baa8484cafa1a106ffaa9c23.jpg
# Downloaded image 1057: https://www.recipetineats.com/wp-content/uploads/2017/07/Beef-Ragu-11a.jpg
# Downloaded image 1058: https://www.supergoldenbakes.com/wordpress/wp-content/uploads/2022/03/Crab_Linguine-1-3.jpg
# Downloaded image 1059: https://www.foodandwine.com/thmb/YRIxnDqYxK66UUgArW6_57jG9AE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/white-fish-risotto-XL-RECIPE2017-8919425b28c246cb976b20dceefbf1c0.jpg
# Downloaded image 1060: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2a72r3X7Pdbx0svN3hfrM3yiK7MOMXzCwSBS3Fe-1XA&s
# Downloaded image 1061: https://thumbs.dreamstime.com/z/mixed-grilled-meat-platter-assorted-delicious-grilled-meat-vegetable-pepper-sauce-vegetables-91013667.jpg
# Downloaded image 1062: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrgu9zPF3pTsGpRU9LgCd5fZNLUqYHQFtLZvKRiulEvQ&s
# Downloaded image 1063: https://www.shutterstock.com/shutterstock/photos/530203870/display_1500/stock-photo-grilled-tiger-shrimps-with-spice-and-lemon-grilled-seafood-530203870.jpg
# Downloaded image 1064: https://www.wellplated.com/wp-content/uploads/2020/02/Baked-Fish-En-Papillote.jpg
# Downloaded image 1065: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQtOvuWMRrJWAfT5R3Wvirf9Q4PV8EK9_rpCWh4DTjNXQ&s
# Downloaded image 1066: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRsdX0K-yRyxY51-R5gJl1dPyeqGjCnfV6nPiU86gT15A&s
# Downloaded image 1067: https://www.simplyrecipes.com/thmb/kO2yxG-lT4gNjwLAREAbrspEsgM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2011__11__italian-meatballs-horiz-c-1800-e83b24e913364fd6b867805335961d65.jpg
# Downloaded image 1068: https://farm8.staticflickr.com/7537/16035876500_6093dc1419_b.jpg
# Downloaded image 1069: https://www.shutterstock.com/image-photo/chicken-soup-vegetables-white-bowl-600nw-1575499510.jpg
# Downloaded image 1070: https://www.shutterstock.com/image-photo/closeup-vegetable-beef-soup-red-260nw-2106758441.jpg
# Downloaded image 1071: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTA_rqEnujXosZwBTVN9N0x32mB0MC8kVNBuqJll1JdIA&s
# Downloaded image 1072: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRN9RyORoNT2vU57lEeJLHoDZz2JUIucTQCFAJOBx7pvg&s
# Downloaded image 1073: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTL37_5Gd4QAm2uC9SXlXbQlfexZl35Wv0f2QZPyql5dQ&s
# Downloaded image 1074: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2vN6I4M3c_ckbtRiGHpPvUvRI6rVEF1t_yyW31ISYfA&s
# Downloaded image 1075: https://www.shutterstock.com/image-photo/close-chicken-mushroom-pie-on-600nw-1965422818.jpg
# Downloaded image 1076: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR-GWRP2ElEgmnFlVQurJblsErncTm4bGxIrMXFwMHlGg&s
# Downloaded image 1077: https://images.immediate.co.uk/production/volatile/sites/30/2020/08/beef-stout-stew-a6d9c78.jpg?quality=90&resize=440,400
# Downloaded image 1078: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReOsUcdJUBwPN_hu78mPFXOxrC07DHDln0-0Shwn08LA&s
# Downloaded image 1079: https://www.simplyrecipes.com/thmb/LnLG3RlDzwwfH6U6N__eElWYSpQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2011__12__chicken-liver-pate-horiz-a-1200-5d5777ad8f974b96a1f557fbc9e7429d.jpg
# Downloaded image 1080: https://cdn.apartmenttherapy.info/image/upload/f_jpg,q_auto:eco,c_fill,g_auto,w_1500,ar_1:1/k%2FPhoto%2FRecipes%2F2022-01_scotch-egg%2F2022-01-05_ATK-0996
# Downloaded image 1081: https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Fish_and_chips_blackpool.jpg/800px-Fish_and_chips_blackpool.jpg
# Downloaded image 1082: https://handletheheat.com/wp-content/uploads/2015/06/beef-empanadas-SQUARE.jpg
# Downloaded image 1083: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6e4BTufu8xI9sr4NGIyKjKPORZVneExmHEQM6xBny1g&s
# Downloaded image 1084: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQMsdEMR1VNoYX5_qmPhLJDIN_joFN_GzffdmXldQEeqw&s
# Downloaded image 1085: https://www.shutterstock.com/image-photo/lobster-roll-on-slate-surface-260nw-267633224.jpg
# Downloaded image 1086: https://www.allrecipes.com/thmb/WSSoRAz2IygrMPkiJxHPbt9gqMg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/8635-southern-fried-chicken-ddmfs_4x3-90736ab31a7a4bb59eb04e2380ccebe7.jpg
# Downloaded image 1087: https://www.allrecipes.com/thmb/GwdML2o-xsFGnHTEp-uy7RWMEOc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/166638-baked-buffalo-wings-ddmfs-beauty-3x4-90787930d20b402e9dde79c22fced332.jpg
# Downloaded image 1088: https://rhubarbandcod.com/wp-content/uploads/2022/06/The-Classic-Cheeseburger-1.jpg
# Downloaded image 1089: https://d1e3z2jco40k3v.cloudfront.net/-/media/5a628a163bab440383da150ea39de9e7.ashx?h=800&amp;la=en-us
# Downloaded image 1090: https://www.shutterstock.com/shutterstock/photos/1295330575/display_1500/stock-photo-hot-baked-potato-topped-with-bacon-green-onions-and-cheddar-cheese-1295330575.jpg
# Downloaded image 1091: https://www.allrecipes.com/thmb/u2jle7sEiO5vkLrIGar0TakjY8s=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/20858-best-ever-jalapeno-poppers-DDMFS-4x3-69772a3d60cd4a63b6dfac0ff415db51.jpg
# Downloaded image 1092: https://www.shutterstock.com/image-photo/homemade-spicy-deviled-eggs-paprika-600nw-256419517.jpg
# Downloaded image 1093: https://www.shutterstock.com/image-photo/dish-delicious-deepfried-calamari-rings-600nw-2344388995.jpg
# Downloaded image 1094: https://www.wellplated.com/wp-content/uploads/2023/05/Oven-Fried-Chicken-Tenders-Recipe.jpg
# Downloaded image 1095: https://www.shutterstock.com/image-photo/plate-delicious-bacon-wrapped-scallops-600nw-1266733525.jpg
# Downloaded image 1096: https://www.shutterstock.com/image-photo/homemade-fried-mozzarella-sticks-marinara-260nw-150708950.jpg
# Downloaded image 1097: https://hips.hearstapps.com/hmg-prod/images/crab-cakes-index-64e7cee7d4dda.jpg?crop=0.8891500963202403xw:1xh;center,top&resize=1200:*
# Downloaded image 1098: https://food.fnr.sndimg.com/content/dam/images/food/fullset/2004/4/21/0/bw2b09_shrimp_cocktail.jpg.rend.hgtvcom.1280.1280.suffix/1557928675507.jpeg
# Downloaded image 1099: https://www.recipetineats.com/wp-content/uploads/2019/01/Baked-Buffalo-Wings_0.jpg
# Downloaded image 1100: https://i2.wp.com/www.downshiftology.com/wp-content/uploads/2023/10/Crab-Stuffed-Mushrooms-main-2.jpg
# Downloaded image 1101: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSC1qaIdAl_qz5VUR9yWiDPmWJS1Ck_986wKb1I0nfm3A&s
# Downloaded image 1102: https://static.emerils.com/styles/wmax-600-sq/public/Fritters.jpg?itok=WQSDmvwK
# Downloaded image 1103: https://www.simplyrecipes.com/thmb/4m-cJOBzwHvJOhtC8h6tSPbG1_8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Smoked-Salmon-Crostini-LEAD-02-a2a2492d16da44378aa1d6a826e2e9a2.jpg
# Downloaded image 1104: https://www.shutterstock.com/shutterstock/photos/1818536438/display_1500/stock-photo-chinese-crab-rangoon-fried-wontons-on-plate-with-red-sauce-1818536438.jpg
# Downloaded image 1105: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSrm-P60BfihCxXgpvjk9Ge1PwtqyjjUDfDy4Bpr1UQg&s
# Downloaded image 1106: https://www.allrecipes.com/thmb/BgOwxHqiCf3EgRxsxPTcn9rF9CA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/8149211-c9122b5df35d42c6894d05bcebce2c72.jpg
# Downloaded image 1107: https://www.simplyrecipes.com/thmb/Gfmp44usm9wMrdjyyLALIi09NWo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Corn-Crabmeat-Chowder-LEAD-5-ac3885c7ef2c4248972ee2a908f38887.jpg
# Downloaded image 1108: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTc1d6ZjpfTo2xw_puvDz8oG_udKPRkuWZdgqIB6K-t3A&s
# Downloaded image 1109: https://media.istockphoto.com/id/137152748/photo/chicken-fillet.jpg?s=612x612&w=0&k=20&c=N-YHf2m5Bisynn-eurqoKnHAen13YHswHZzdtu-1ovw=
# Downloaded image 1110: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0wWe_MkwqKPz3m-PcdgWQkRvWIqVnGzgWgLuQs-4Nbw&s
# Downloaded image 1111: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTVbiOGzCGNNq-5gLdshZi7BjUwoZtUUgLg5iq7ZVipDw&s
# Downloaded image 1112: https://www.shutterstock.com/image-photo/homemade-creamy-oysters-rockefeller-cheese-260nw-385915237.jpg
# Downloaded image 1113: https://www.shutterstock.com/image-photo/pan-delicious-fresh-homemade-cajun-260nw-488586964.jpg
# Downloaded image 1114: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQT9jw4XQKMTNDhYbqwKQvF0o2dIqtyfHwBVB8oeul0cg&s
# Downloaded image 1115: https://mojo.generalmills.com/api/public/content/JkWfbsGspk-1188E3B3qgw_gmi_hi_res_jpeg.jpeg?v=3585536b&t=466b54bb264e48b199fc8e83ef1136b4
# Downloaded image 1116: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjF_nHPb2568AQZfunPSBgoY502__ua4TbuHb0wtiJ6g&s
# Downloaded image 1117: https://www.thespruceeats.com/thmb/KCt7H7pD7MJ0LeTbg6kLB8OAwPM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/italian-buttery-garlic-crab-bruschetta-1300497-hero-04-d0526c0eb2fc4904ba36199a09c4df38.jpg
# Downloaded image 1118: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrPp5LRSjDHJ9VDv7y6M74E1Z25TlrOMT2QMpU5uBBjQ&s
# Downloaded image 1119: https://images.immediate.co.uk/production/volatile/sites/30/2021/04/Crab-and-saffron-risotto-3360182.jpg?resize=768,574
# Downloaded image 1120: https://www.shutterstock.com/image-photo/frying-pan-tasty-trout-fish-600nw-675807403.jpg
# Downloaded image 1121: https://img.sndimg.com/food/image/upload/q_92,fl_progressive,w_1200,c_scale/v1/img/recipes/35/19/32/pic66kbuy.jpg
# Downloaded image 1122: https://i2.wp.com/www.downshiftology.com/wp-content/uploads/2023/07/Crab-Salad-main.jpg
# Downloaded image 1123: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQiSGljBFeOD3ISl5IXZib_fLq6n9E0PhxqZ6ngsNpBBQ&s
# Downloaded image 1124: https://www.allrecipes.com/thmb/SoBuPU73KcbYHl3Kp3j8Xx4A3fc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/8805-CrispyFriedChicken-mfs-3x2-072-d55b8406d4ae45709fcdeb58a04143c2.jpg
# Downloaded image 1125: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRI7Mzn9asApEpnZ-S-0DigbkHiOxMyqILHikxtfm332g&s
# Downloaded image 1126: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRgoFSOCFqm3tI5PNyrVqNz17br6Rnhh98MtmovKdI5A&s
# Downloaded image 1127: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQu4ewENbIFyzCYY-T1HHsAdigOTPGHHq2jn4UuXp8mDA&s
# Downloaded image 1128: https://hips.hearstapps.com/delish/assets/17/04/1485369256-chicken-parm-bitesl1.jpg
# Downloaded image 1129: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQz0jIZrYBRziL-4xbvBNkfAaYzucq81h25MESl6GT6lQ&s
# Downloaded image 1130: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6ke8MgoDtp2x1c09zt98CF516Sp_0UQHQ1mnJjiKo-g&s
# Downloaded image 1131: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpL1Lcvom8KZQZKuJxGHgzMAwfz-pgFs8uY6eAZtUjZg&s
# Downloaded image 1132: https://www.indianhealthyrecipes.com/wp-content/uploads/2021/07/egg-fried-rice-recipe.jpg
# Downloaded image 1133: https://www.recipetineats.com/wp-content/uploads/2016/04/Thai-Fish-Cakes-landscape.jpg
# Downloaded image 1134: https://www.shutterstock.com/image-photo/thai-style-spicy-chicken-wings-260nw-242109895.jpg
# Downloaded image 1135: https://www.shutterstock.com/image-photo/pad-thai-600nw-366360143.jpg
# Downloaded image 1136: https://www.recipetineats.com/wp-content/uploads/2019/02/Thai-Green-Curry_5.jpg
# Downloaded image 1137: https://www.shutterstock.com/image-photo/thai-drunken-noodles-pad-kee-600nw-1655549911.jpg
# Downloaded image 1138: https://www.shutterstock.com/image-photo/crab-fried-rice-thai-style-600nw-1718552239.jpg
# Downloaded image 1139: https://www.shutterstock.com/image-photo/tom-yum-goong-thai-hot-260nw-497390089.jpg
# Downloaded image 1140: https://www.licious.in/blog/wp-content/uploads/2021/03/egg-pakoda-1-600x600.jpg
# Downloaded image 1141: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWMgIA4SQQixDsckIkN6Df0J2z2vV-fNgcO_ie_wadlw&s
# Downloaded image 1142: https://www.licious.in/blog/wp-content/uploads/2020/12/Tandoori-Fish.jpg
# Downloaded image 1143: https://static.toiimg.com/photo/75356205.cms
# Downloaded image 1144: https://natashaskitchen.com/wp-content/uploads/2020/10/Egg-Rolls-4.jpg
# Downloaded image 1145: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTcYYe4tv1G83wa7oNF43W9KM6sGlkFMn98adwUniqKeA&s
# Downloaded image 1146: https://www.masala.tv/wp-content/uploads/2021/06/Nawabi-Fish-Karahii.jpg
# Downloaded image 1147: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKIgAPyXdkkkAeW1Ms45SLO6_ZAh0uxcgRshskJfdS8w&s
# Downloaded image 1148: https://img-global.cpcdn.com/recipes/e456480d88c6b5ad/400x400cq70/photo.jpg
# Downloaded image 1149: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZMI6ECr9h7fdJktWeXOkqVNfqPSk-zrkQ9F-fJ_5hog&s
# Downloaded image 1150: https://www.simplyrecipes.com/thmb/RrIT5GcxpHru0ZHis39-wyXADNg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2017__12__2017-12-Chicken-Fried-Rice-3-c98348ac2e4545d9a3e637a780f09b70.jpg
# Downloaded image 1151: https://www.allrecipes.com/thmb/nKyhKSQNe3cWKPlDnV3LvyYgrDI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/609167-fcde3d214a3b4ee49eaf679ad46198d1.jpg
# Image download process completed.

# %%
def download_image(image_url, output_directory, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            response = requests.get(image_url, stream=True)
            if response.status_code == 200:
                with open(output_directory, 'wb') as file:
                    file.write(response.content)
                return True
            else:
                print(f"Failed to download image from {image_url}. Status code: {response.status_code}")
                retries += 1
        except Exception as e:
            print(f"An error occurred while downloading image from {image_url}: {str(e)}")
            retries += 1
    print(f"Max retries reached. Failed to download image {image_url}")
    return False

# %%
def download_recipe_images(data, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    if 'image_url' not in data.columns:
        print("Error: 'image_url' column not found in the dataset.")
        return

    failed_images = []

    for index, row in data.iterrows():
        image_url = row['image_url']
        image_filename = f"{index}.jpg"
        image_path = os.path.join(output_directory, image_filename)

        if download_image(image_url, image_path):
            print(f"Downloaded image {index}: {image_url}")
        else:
            failed_images.append((index, image_url))

    # Retry downloading failed images
    for index, image_url in failed_images:
        image_filename = f"{index}.jpg"
        image_path = os.path.join(output_directory, image_filename)
        if download_image(image_url, image_path):
            print(f"Retried downloading image {index}: {image_url}")
        else:
            print(f"Failed to download image {index}: {image_url}")

    print("Image download process completed.")

# %%
# Example usage
# Assuming 'recipes.csv' is your dataset containing 'image_url' column
# and you want to download images to 'images' directory
dataset_path = 'fusionrecipe.csv'
output_directory = 'recfus_img'

# Load the dataset
data = pd.read_csv(dataset_path)

# %%
# Download recipe images
download_recipe_images(data, output_directory)
# Out:
# Downloaded image 0: https://media.istockphoto.com/id/691985214/photo/homemade-deep-fried-indian-flatbread.jpg?s=612x612&w=0&k=20&c=ppXX9cvP4SUOSaI4xlSqRuqGzeURvVEzWV2u3ZKpVbQ=
# Downloaded image 1: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1207175/dscf3709_full.jpg
# Downloaded image 2: https://s3.amazonaws.com/grecipes/public/pictures/recipes/37540/cabbage_salad_full.jpg
# Downloaded image 3: http://grecipes.s3.amazonaws.com/recipe_picture/1498249/full_uploads_20140617T0730Z_ace0df8560959563e0c5dc2af698b2da_shepuchi_bhaji3.jpg
# Downloaded image 4: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1229240/beetroot%20cutlet%20-%201_full.jpg
# Downloaded image 5: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1137932/dsc04540_full.jpg
# Downloaded image 6: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1093441/gajarkahalwa_full.jpg
# Downloaded image 7: http://grecipes.s3.amazonaws.com/recipe_picture/1501128/full_uploads_20140710T0641Z_b725a107b1484f4defc76757eeba63e0_IMG_7177.jpg
# Downloaded image 8: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1409113/befunky_dscn6959edited.jpg_full.jpg
# Downloaded image 9: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1137942/dsc04499_full.jpg
# Downloaded image 10: http://grecipes.s3.amazonaws.com/recipe_picture/1512110/full_doodhi_thepla1.jpg
# Downloaded image 11: https://s3.amazonaws.com/grecipes/public/pictures/recipes/821928/pav_bhaji_full.jpg
# Downloaded image 12: https://healthynibblesandbits.com/wp-content/uploads/2020/01/Saag-Paneer-FF.jpg
# Downloaded image 13: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1061865/img_5341_full.jpg
# Downloaded image 14: http://grecipes.s3.amazonaws.com/recipe_picture/1626512/full_uploads_20200911T1347Z_b289ba95a260bff325d18c4f7d0902d9_Jeera-aloo-foodpanda.jpg
# Downloaded image 15: https://img-global.cpcdn.com/recipes/2f8496835725af3d/680x482cq70/veggies-delight-pizza-recipe-main-photo.webp
# Downloaded image 16: https://beingnutritious.com/wp-content/uploads/2022/11/Stuffed-Mushrooms-9-scaled.jpg
# Downloaded image 17: https://i0.wp.com/faithfulplateful.com/wp-content/uploads/2018/11/lentil-vegetable-soup-1620160-scaled.jpg?resize=600%2C912&ssl=1
# Downloaded image 18: https://media.istockphoto.com/id/478249440/photo/tabbouleh-salad-with-quinoa-parsley-and-vegetables.jpg?s=612x612&w=0&k=20&c=zktRYgRomMrXb3dDdx-4-UFFG2gK-d-N6kmMaQCJjqQ=
# Downloaded image 19: https://www.easycheesyvegetarian.com/wp-content/uploads/2023/06/chickpea-stir-fry-7-1024x1536.jpg
# Downloaded image 20: https://cdn.loveandlemons.com/wp-content/uploads/2019/09/eggplant-parmesan.jpg
# Downloaded image 21: https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F43%2F2023%2F01%2F30%2F14041-delicious-black-bean-burritos-ddmfs-3x2-008.jpg&q=60&c=sc&poi=auto&orient=true&h=512
# Downloaded image 22: https://www.shutterstock.com/image-photo/stack-spanakopita-piece-pie-homemade-260nw-2378970187.jpg
# Downloaded image 23: https://cdn.loveandlemons.com/wp-content/uploads/2023/01/mushroom-risotto-recipe.jpg
# Downloaded image 24: https://cdn.loveandlemons.com/wp-content/uploads/2021/08/caprese-skewers-1.jpg
# Downloaded image 25: http://grecipes.s3.amazonaws.com/recipe_picture/1423988/full_vegetarian-chilli-shepherds-pie-from-the-oven.jpg
# Downloaded image 26: http://grecipes.s3.amazonaws.com/recipe_picture/1501938/full_ds_20140716T1436Z_da9cbeae31c1e180f402d896f04bc145_Stir_fried_vegetarian_mutton_453x640_453x640_.jpg
# Downloaded image 27: http://grecipes.s3.amazonaws.com/recipe_picture/1451914/full_no-guilt-chile.jpg
# Downloaded image 28: http://grecipes.s3.amazonaws.com/recipe_picture/1501940/full_uploads_20140716T1448Z_7abdcee1ce339b51f57f93368dfba42e_vegetarian_mutton_nasi_lemak_390x400_.jpg
# Downloaded image 29: http://grecipes.s3.amazonaws.com/recipe_picture/1512713/full_uploads_20141013T1743Z_8692fa5f1657892c3dda88e8baaf0c34_IMG_5604.JPG
# Downloaded image 30: https://s3.amazonaws.com/grecipes/public/pictures/recipes/373127/marrow_full.jpg
# Downloaded image 31: http://grecipes.s3.amazonaws.com/recipe_picture/1588224/full_uploads_20171207T0219Z_f377c615aea3336737a3c0d5a503d6db_GreenBeanCarrotMushroomMedleyP1010846.JPG
# Downloaded image 32: http://grecipes.s3.amazonaws.com/recipe_picture/1519097/full_TVP_spaghetti_sauce.png
# Downloaded image 33: https://s3.amazonaws.com/grecipes/public/pictures/recipes/861183/potato-skins_full.jpg
# Downloaded image 34: http://grecipes.s3.amazonaws.com/recipe_picture/1502423/full_uploads_20140720T1813Z_1f4510895473deaee36ddd20c7563ff2_2.jpg
# Downloaded image 35: http://grecipes.s3.amazonaws.com/recipe_picture/1442551/full_vegetarian-chili.jpg
# Downloaded image 36: http://grecipes.s3.amazonaws.com/recipe_picture/1516161/full_uploads_20141110T0258Z_6d8be58f0d89d4b3bb063d05151a6353_vegetarian_fried_mee_hoon.jpg
# Downloaded image 37: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1060435/mohanthal_full.jpg
# Downloaded image 38: https://s3.amazonaws.com/grecipes/public/pictures/recipes/504121/vege_tofu_stir_fry_full.jpg
# Downloaded image 39: https://s3.amazonaws.com/grecipes/public/pictures/recipes/39365/basmati_rice_full.jpg
# Downloaded image 40: https://s3.amazonaws.com/grecipes/public/pictures/recipes/754253/onion_bhajis0004_full.jpg
# Downloaded image 41: https://www.shutterstock.com/image-photo/monsoon-special-moong-dal-vada-600nw-1933277675.jpg
# Downloaded image 42: https://s3.amazonaws.com/grecipes/public/pictures/recipes/433297/malai_kofta1_full.jpg
# Downloaded image 43: https://s3.amazonaws.com/grecipes/public/pictures/recipes/865570/tepla__1__full.jpg
# Downloaded image 44: https://s3.amazonaws.com/grecipes/public/pictures/recipes/915438/atta_chakuli_full.jpg
# Downloaded image 45: http://grecipes.s3.amazonaws.com/recipe_picture/1498246/full_uploads_20140617T0726Z_b63f2d2358b7a90a6485f2df4408440b_masale_bhat1.jpg
# Downloaded image 46: http://grecipes.s3.amazonaws.com/recipe_picture/1439516/full_aamras-puri2.jpg
# Downloaded image 47: http://grecipes.s3.amazonaws.com/recipe_picture/1531584/full_Kesar_Pista_Kulfi3.jpg
# Downloaded image 48: https://s3.amazonaws.com/grecipes/public/pictures/recipes/9297/dry_potatoes_full.jpg
# Downloaded image 49: http://grecipes.s3.amazonaws.com/recipe_picture/1566114/uploads_20160823T0415Z_c5638816c58b3258f2d0463a8a5f239c_kesar-peda-indian-spicyvegrecipes.jpg
# Downloaded image 50: http://grecipes.s3.amazonaws.com/recipe_picture/1426198/522976-332658606801992-41013208-n.jpg
# Downloaded image 51: http://grecipes.s3.amazonaws.com/recipe_picture/1556987/0dfc088de82286d61309d9_Easy_Rock_Cheese_Toast_-_Crispy_Veg_Rava_Appetizer_Quick_Suji_Bread_Toast.jpg
# Downloaded image 52: http://grecipes.s3.amazonaws.com/recipe_picture/1516213/Nankhatai_Recipe_How_To_Make_Nankhatai_Eggless_Indian_Cookies.JPG
# Downloaded image 53: https://s3.amazonaws.com/grecipes/public/pictures/recipes/896013/scrap.jpg
# Downloaded image 54: https://2.bp.blogspot.com/-XBnc8RVmaRQ/UQP4uwoIMFI/AAAAAAAAL2I/OBNDg5krYME/s1600/IMG_2458.jpg
# Downloaded image 55: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free49.jpg
# Downloaded image 56: https://2.bp.blogspot.com/-F9iGc1iUrkw/TppUWBWpp0I/AAAAAAAABu8/y4iVIAtlze4/s1600/P1040905.JPG
# Downloaded image 57: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free322.jpg
# Downloaded image 58: http://grecipes.s3.amazonaws.com/recipe_picture/1525464/uploads_20150209T0438Z_cad56dbc530b8efabd5b65ad39c45bcc_1.165a_479x640_.jpg
# Downloaded image 59: http://grecipes.s3.amazonaws.com/recipe_picture/1525464/uploads_20150209T0438Z_cad56dbc530b8efabd5b65ad39c45bcc_1.165a_479x640_.jpg
# Downloaded image 60: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free134.jpg
# Downloaded image 61: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free44.jpg
# Downloaded image 62: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free34.jpg
# Downloaded image 63: http://grecipes.s3.amazonaws.com/recipe_picture/1506439/uploads_20140824T1845Z_cf6766bb98f57b2f981537399365eef3_DSCN1311.JPG
# Downloaded image 64: https://lh3.googleusercontent.com/blogger_img/APIUysgqD0ILJHxn0SmExxDzBIP2teEiQu2cQwKHoquKABPHqMbxVroFs25RcdDHwlM7d7P17jzva7_HcLt81w=s1600
# Downloaded image 65: https://3.bp.blogspot.com/_EosO2d3aJ3E/S1xMqm1aGoI/AAAAAAAAADc/J6GCDB0Wf8U/s1600/5.jpg
# Downloaded image 66: https://www.shutterstock.com/image-photo/mix-vegetable-masala-khichdi-khichuri-260nw-1751130722.jpg
# Downloaded image 67: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free135.jpg
# Downloaded image 68: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free138.jpg
# Downloaded image 69: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free121.jpg
# Downloaded image 70: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free123.jpg
# Downloaded image 71: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free199.jpg
# Downloaded image 72: https://www.shutterstock.com/shutterstock/photos/566019145/display_1500/stock-photo-methi-paratha-thepla-indian-flat-bread-using-fenugreek-leaves-selective-focus-566019145.jpg
# Downloaded image 73: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free12.JPG
# Downloaded image 74: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free509.jpg
# Downloaded image 75: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free505.jpg
# Downloaded image 76: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free503.jpg
# Downloaded image 77: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free500.jpg
# Downloaded image 78: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free24.JPG
# Downloaded image 79: https://www.recipe-free.com/index_archivos/images/img_recetas/g/recipe-free309.jpg
# Downloaded image 80: https://www.shutterstock.com/image-photo/chole-chana-masala-spicy-chickpeas-600nw-619036925.jpg
# Downloaded image 81: https://www.shutterstock.com/image-photo/punjabi-kadhi-pakoda-curry-pakora-260nw-1111862825.jpg
# Downloaded image 82: https://media.istockphoto.com/id/1249888822/photo/a-bowl-of-palak-paneer-made-of-paneer-cheese-dipped-in-mildly-spiced-spinach-gravy.jpg?s=612x612&w=0&k=20&c=OoenVkEGXIEeOtxPVn1tUNQuk1cn1PBtmJIy0nIzfDY=
# Downloaded image 83: https://somethingiscooking.com/wp-content/uploads/2017/01/MethiThepla1.jpg
# Downloaded image 84: https://smithakalluraya.com/wp-content/uploads/2017/03/VEG-JALFREZI.jpg
# Downloaded image 85: https://media.istockphoto.com/id/1170374719/photo/dal-makhani-at-dark-background.jpg?s=612x612&w=0&k=20&c=49yLaUAE2apakVk2AAiRQimZd98WtSjIQ0hzCzWsmns=
# Downloaded image 86: https://img.freepik.com/premium-photo/indian-style-suran-sabzi-jimikand-sabji-also-known-as-elephant-foot-yam-ole-stir-fried-recipe_466689-83249.jpg
# Downloaded image 87: https://indianvegrecipe.com/wp-content/uploads/2019/08/veg-handi-recipe.jpg
# Downloaded image 88: https://media.istockphoto.com/id/1146289003/photo/traditional-indian-street-food-rice-with-vegetables-close-up-on-a-plate-horizontal.jpg?s=612x612&w=0&k=20&c=Ikb_QsWs1yjKMs8izmdkAjUc2BAiBQCLOzL9uWZ7-aY=
# Downloaded image 89: https://img.freepik.com/free-photo/vertical-shot-traditional-indian-paneer-butter-masala-cheese-cottage-curry-black-surface_181624-32001.jpg
# Downloaded image 90: https://st4.depositphotos.com/19960896/23009/i/450/depositphotos_230092660-stock-photo-matar-paneer-curry-recipe-made.jpg
# Downloaded image 91: https://www.spiceupthecurry.com/wp-content/uploads/2021/08/methi-matar-malai-1-500x375.jpg
# Downloaded image 92: https://st2.depositphotos.com/49005766/46430/i/450/depositphotos_464301590-stock-photo-indian-breakfast-puri-chickpea-chana.jpg
# Downloaded image 93: https://cdn.pixabay.com/photo/2024/01/29/21/50/ai-generated-8540840_640.jpg
# Downloaded image 94: https://st3.depositphotos.com/5653638/16138/i/450/depositphotos_161386366-stock-photo-indian-street-food-vada-pav.jpg
# Downloaded image 95: https://img.freepik.com/free-photo/traditional-indian-soup-lentils-indian-dhal-spicy-curry-bowl-spices-herbs-rustic-black-wooden-table_2829-18717.jpg
# Downloaded image 96: https://st3.depositphotos.com/5653638/14980/i/450/depositphotos_149807346-stock-photo-paneer-butter-masala-or-cheese.jpg
# Downloaded image 97: https://images.pexels.com/photos/17223835/pexels-photo-17223835.jpeg?cs=srgb&dl=pexels-aditya-mara-17223835.jpg&fm=jpg
# Downloaded image 98: https://st2.depositphotos.com/5653638/11489/i/950/depositphotos_114898966-stock-photo-cooked-red-kidney-beans-curry.jpg
# Downloaded image 99: https://img.freepik.com/premium-photo/paneer-tikka-is-indian-dish-made-from-chunks-cottage-cheese-marinated-spices-grilled-tandoor_466689-76786.jpg
# Downloaded image 100: https://st3.depositphotos.com/5653638/16094/i/450/depositphotos_160945314-stock-photo-gobi-manchurian-dry-popular-street.jpg
# Downloaded image 101: https://st2.depositphotos.com/5653638/45282/i/450/depositphotos_452822374-stock-photo-malai-kofta-curry-indian-cuisine.jpg
# Downloaded image 102: https://www.masterindian.com/cdn/shop/articles/blog-aloo-gobi_1024x1024.png?v=1552147488
# Downloaded image 103: https://i0.wp.com/cookingfromheart.com/wp-content/uploads/2016/07/Pulihora-5.jpg?resize=533%2C800&ssl=1
# Downloaded image 104: https://st2.depositphotos.com/5653638/11749/i/450/depositphotos_117498296-stock-photo-indian-snacks-bhel-puri-served.jpg
# Downloaded image 105: https://www.shutterstock.com/image-photo/alu-vadi-patra-colocasia-taro-600nw-1977101867.jpg
# Downloaded image 106: https://myfoodstory.com/wp-content/uploads/2021/05/Masala-Vada-2.jpg
# Downloaded image 107: https://i0.wp.com/myspicetrunk.com/wp-content/uploads/2020/12/WhatsApp-Image-2020-12-03-at-1.07.42-PM-720x1059.jpeg?resize=720%2C1059&ssl=1
# Downloaded image 108: https://www.indianhealthyrecipes.com/wp-content/uploads/2022/03/bombay-sandwich-recipe.jpg.webp
# Downloaded image 109: https://www.shutterstock.com/image-vector/vector-illustration-sadhya-south-indian-260nw-2025224885.jpg
# Downloaded image 110: https://st2.depositphotos.com/3147737/5401/i/450/depositphotos_54019723-stock-photo-curd-rice-a-rice-mixed.jpg
# Downloaded image 111: https://st2.depositphotos.com/5653638/11521/i/950/depositphotos_115216222-stock-photo-dhokla-indian-foodgujarati-khaman-dhokla.jpg
# Downloaded image 112: https://storage.needpix.com/rsynced_images/avial-3688449_1280.jpg
# Downloaded image 113: https://upload.wikimedia.org/wikipedia/commons/0/04/Bisi_Bele_Bath_%28Bisibelebath%29.JPG
# Downloaded image 114: https://st3.depositphotos.com/5653638/15354/i/450/depositphotos_153549556-stock-photo-baigan-bharta-in-hindi-or.jpg
# Downloaded image 115: https://www.shutterstock.com/image-photo/ilish-panta-bengali-new-year-260nw-2139153519.jpg
# Downloaded image 116: https://www.shutterstock.com/image-photo/homemade-indian-spicy-eggplant-potato-600nw-664554715.jpg
# Downloaded image 117: https://st.depositphotos.com/5653638/60062/i/450/depositphotos_600626504-stock-photo-lasooni-palak-recipe-dhaba-style.jpg
# Downloaded image 118: https://st2.depositphotos.com/5653638/11508/i/450/depositphotos_115082614-stock-photo-pani-puri-or-panipuri-golgappe.jpg
# Downloaded image 119: https://www.shutterstock.com/image-photo/sev-batata-puri-papdi-chat-260nw-673732282.jpg
# Downloaded image 120: https://www.shutterstock.com/image-photo/dahi-puri-snack-popular-state-600nw-369255617.jpg
# Downloaded image 121: https://st2.depositphotos.com/5653638/11522/i/450/depositphotos_115225994-stock-photo-indian-masala-fried-bhindi-or.jpg
# Downloaded image 122: https://www.shutterstock.com/image-photo/fresh-green-mint-chutney-made-600nw-1750888160.jpg
# Downloaded image 123: https://www.shutterstock.com/image-photo/baghare-baingan-masala-eggplant-brinjal-600nw-1971619283.jpg
# Downloaded image 124: https://img.freepik.com/free-photo/pakistani-food-cloth-top-view_23-2148825097.jpg?size=626&ext=jpg&ga=GA1.1.1395880969.1709683200&semt=ais
# Downloaded image 125: https://img.freepik.com/premium-photo/indian-vegetable-pulav-biryani-made-using-basmati-rice-served-terracotta-bowl-selective-focus_466689-55615.jpg
# Downloaded image 126: https://www.shutterstock.com/image-photo/methi-malai-paneer-creamy-fenugreek-260nw-617034299.jpg
# Downloaded image 127: https://www.shutterstock.com/image-photo/patta-gobi-sabji-cabbage-sabzi-600nw-682332448.jpg
# Downloaded image 128: https://st4.depositphotos.com/19960896/31012/i/450/depositphotos_310126572-stock-photo-undhiyu-gujarati-mixed-vegetable-dish.jpg
# Downloaded image 129: https://img.freepik.com/premium-photo/punjabi-kadhi-pakoda-curry-pakora-indian-cuisine-served-bowl-karahi_466689-27014.jpg
# Downloaded image 130: https://st.depositphotos.com/5653638/60277/i/450/depositphotos_602772658-stock-photo-palak-sweet-corn-sabzi-also.jpg
# Downloaded image 131: https://www.balancenutrition.in/images/receipe-img/1436605226_large.jpg
# Downloaded image 132: https://st4.depositphotos.com/13349234/29321/i/450/depositphotos_293212704-stock-photo-potatoes-cumin-bowl.jpg
# Downloaded image 133: https://www.shutterstock.com/image-photo/paneer-bhurji-mildly-spiced-cottage-260nw-1261243846.jpg
# Downloaded image 134: https://betterfoodguru.com/wp-content/uploads/2021/03/Chana-Saag-Aloo-scaled.jpg
# Downloaded image 135: https://media.istockphoto.com/id/1186759790/photo/paneer-tikka-at-skewers-in-black-bowl-at-dark-slate-background-paneer-tikka-is-an-indian.jpg?s=612x612&w=0&k=20&c=cITToqM1KEnrixXjoLhEciqP24SxdKtW3QXykq-W5OE=
# Downloaded image 136: https://www.shutterstock.com/image-photo/healthy-nutritious-indian-comfort-food-260nw-1954017742.jpg
# Downloaded image 137: https://media.istockphoto.com/id/1225951695/photo/lachha-paratha-flatbread-on-brass-plate-isolated.jpg?s=612x612&w=0&k=20&c=L7yLXjt4lgTOWTOQ_3bqxvCLcmb7MVe2UNOgrolO9i8=
# Downloaded image 138: https://media.istockphoto.com/id/1413566368/photo/indian-food-aloo-paratha-or-indian-potato-stuffed-flatbread-served-with-butter-pickle-and.jpg?s=612x612&w=0&k=20&c=hIqRXgQTFJ4Ta_Zh_JhOc_Okjk_yJUB--uDYIjifVCc=
# Downloaded image 139: https://st.depositphotos.com/1491432/2659/i/450/depositphotos_26595855-stock-photo-sambar-idli-or-sambar-idly.jpg
# Downloaded image 140: https://www.shutterstock.com/image-photo/dahi-vada-bhalla-type-chaat-600nw-1934860373.jpg
# Downloaded image 141: https://media.istockphoto.com/id/1365859011/photo/drink-mango-lassi-in-two-glasses-on-rustic-concrete-table-with-fresh-ripe-cut-manfo-from-above.jpg?s=612x612&w=0&k=20&c=uHnr_0raQDe2sgUYHdP5GSa2raaj3ILG4m1cmFHtVJA=
# Downloaded image 142: https://www.shutterstock.com/image-photo/overhead-view-veg-kadai-curry-260nw-1935510700.jpg
# Downloaded image 143: https://media.istockphoto.com/id/515853026/photo/traditional-rasmalai-or-ras-malai-indian-dessert-bengali-sweet.jpg?s=612x612&w=0&k=20&c=LYftdDAkIa8lVyfmwt8iK-OPSQr2KCcJcYpPhbFtFBk=
# Downloaded image 144: https://www.shutterstock.com/image-photo/paneer-chilli-indo-chinese-cuisine-600nw-1876336663.jpg
# Downloaded image 145: https://img.freepik.com/free-photo/semiya-payasam-shewai-sewai-khir-seviyan-kheer-is-indian-sweet-made-with-vermicelli-milk-ghee-sugar-jaggery-raisins-nuts_466689-75455.jpg?size=626&ext=jpg&ga=GA1.1.735520172.1710288000&semt=ais
# Downloaded image 146: https://www.funfoodfrolic.com/wp-content/uploads/2020/04/Paneer-Jalfrezi.jpg
# Downloaded image 147: https://media.istockphoto.com/id/1124973765/photo/chicken-curry.jpg?s=612x612&w=0&k=20&c=YTjPGlfvT7pHiy1RX8ZcoizSdUEE9ocOAEF65H4QgJA=
# Downloaded image 148: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1161828/paneer-fried-rice_full.jpg
# Downloaded image 149: https://s3.amazonaws.com/grecipes/public/pictures/recipes/7272/korma-rice-ck-1031654-l_full.jpg
# Downloaded image 150: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1128582/img_1313[2]_full.jpg
# Downloaded image 151: https://www.shutterstock.com/image-photo/classic-fruit-nut-indian-pilau-260nw-108269183.jpg
# Downloaded image 152: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1221481/sambar_full.jpg
# Downloaded image 153: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1322952/202_large_capsicum-tofu_full.jpg
# Downloaded image 154: http://grecipes.s3.amazonaws.com/recipe_picture/1459084/full_Indian-mango-pickle-B-.jpg
# Downloaded image 155: https://s3.amazonaws.com/grecipes/public/pictures/recipes/431506/carrot_halwa_full.jpg
# Downloaded image 156: https://s3.amazonaws.com/grecipes/public/pictures/recipes/849179/dsc02656_full.jpg
# Downloaded image 157: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1074687/kjamun5_full.jpg
# Downloaded image 158: https://s3.amazonaws.com/grecipes/public/pictures/recipes/1132342/img_20120129_110819_full.jpg
# Downloaded image 159: http://grecipes.s3.amazonaws.com/recipe_picture/1442514/full_dhoodhpeda.jpg
# Downloaded image 160: https://www.shutterstock.com/image-photo/bharwa-karela-masala-fry-stuffed-260nw-2101741081.jpg
# Downloaded image 161: https://www.shutterstock.com/image-photo/rice-mixed-vegetables-260nw-361713575.jpg
# Downloaded image 162: https://www.shutterstock.com/shutterstock/videos/5965445/thumb/1.jpg?ip=x480
# Downloaded image 163: https://media.istockphoto.com/id/1209898811/photo/chapati-wrap-with-cheese-vegetarian-food.jpg?s=612x612&w=0&k=20&c=nSbQOQrOq4W2VDYlazvsX9BERrqPekAM5KIEMf0kwCU=
# Downloaded image 164: https://www.shutterstock.com/image-photo/stir-fried-taro-roots-arbi-600nw-1858324504.jpg
# Downloaded image 165: https://www.shutterstock.com/image-photo/paneer-bhurji-gravy-served-bowl-260nw-1597943206.jpg
# Downloaded image 166: https://www.shutterstock.com/image-photo/green-peas-stuffed-flat-bread-260nw-783950896.jpg
# Downloaded image 167: https://www.shutterstock.com/image-photo/healthy-food-oats-chilla-veggies-260nw-2256544083.jpg
# Downloaded image 168: https://www.shutterstock.com/image-photo/dum-handi-gosht-pilaf-prepared-260nw-1995758066.jpg
# Downloaded image 169: https://www.shutterstock.com/image-photo/malabar-fresh-homecooked-parotta-handmade-260nw-1857393661.jpg
# Downloaded image 170: https://www.shutterstock.com/image-photo/shakkar-pare-shakkarpare-shankar-pale-260nw-2221241253.jpg
# Downloaded image 171: https://www.shutterstock.com/image-photo/paneer-korma-kurma-quorma-popular-260nw-1595283805.jpg
# Downloaded image 172: https://www.shutterstock.com/image-photo/pakora-pakoda-traditional-popular-indian-260nw-1011403585.jpg
# Downloaded image 173: https://www.shutterstock.com/image-photo/cumin-rice-jeera-popular-indian-260nw-1785410987.jpg
# Downloaded image 174: https://www.shutterstock.com/image-photo/veg-poha-cutlet-flattened-rice-260nw-1574859061.jpg
# Downloaded image 175: https://www.shutterstock.com/image-photo/top-view-indian-aloo-palak-600w-1874767843.jpg
# Downloaded image 176: https://www.shutterstock.com/image-photo/daikon-radish-mooli-muli-paratha-260nw-523414645.jpg
# Downloaded image 177: https://www.shutterstock.com/image-photo/khajur-barfi-khajoor-dry-fruits-260nw-2261200797.jpg
# Downloaded image 178: https://www.shutterstock.com/image-photo/palak-paneer-curry-made-spinach-260nw-620912093.jpg
# Downloaded image 179: https://www.shutterstock.com/image-photo/roasted-phool-makhana-crispy-masala-260nw-2067202442.jpg
# Downloaded image 180: https://www.shutterstock.com/image-photo/namkeen-kasuri-methi-masala-mathri-260nw-2269061467.jpg
# Downloaded image 181: https://www.shutterstock.com/image-photo/sweet-dink-laddu-known-dinkache-260nw-1600091485.jpg
# Downloaded image 182: https://www.shutterstock.com/image-photo/indian-phool-gobi-shimla-mirch-260nw-2443419187.jpg
# Downloaded image 183: https://www.shutterstock.com/image-photo/bhindi-masala-ladies-finger-fry-600nw-2148588109.jpg
# Downloaded image 184: https://www.shutterstock.com/shutterstock/photos/1782726167/display_1500/stock-photo-aluwadi-paatra-maharashtrian-and-gujrati-snack-recipe-made-using-colocasia-leaves-1782726167.jpg
# Downloaded image 185: https://media.istockphoto.com/id/1146289003/photo/traditional-indian-street-food-rice-with-vegetables-close-up-on-a-plate-horizontal.jpg?s=170667a&w=is&k=20&c=Fsf_b9GAFNNuaRXbasuMGt3ziMBfIRzb-WW6nwlIsuQ=
# Downloaded image 186: https://www.shutterstock.com/image-photo/gulab-jamuns-indian-dessert-topped-600nw-295395848.jpg
# Downloaded image 187: https://www.shutterstock.com/image-photo/dahi-vada-bhalla-type-chaat-600nw-1934860373.jpg
# Downloaded image 188: https://www.shutterstock.com/image-photo/tasty-spicy-chana-pulao-pulav-600nw-1899309709.jpg
# Downloaded image 189: https://www.shutterstock.com/image-photo/aloo-mutter-matar-aalu-dry-600nw-1899776431.jpg
# Downloaded image 190: https://www.shutterstock.com/image-photo/homemade-roti-chapati-flatbread-on-260nw-1902815578.jpg
# Downloaded image 191: https://www.shutterstock.com/shutterstock/photos/2095156876/display_1500/stock-photo-aloo-mutter-is-a-punjabi-dish-from-the-indian-subcontinent-which-is-made-from-potatoes-and-peas-in-2095156876.jpg
# Downloaded image 192: https://www.shutterstock.com/image-photo/palak-paneer-curry-made-spinach-260nw-620862155.jpg
# Downloaded image 193: https://www.shutterstock.com/image-photo/matar-paneer-curry-recipe-made-260nw-1250565787.jpg
# Downloaded image 194: https://www.shutterstock.com/image-photo/indian-traditional-chats-kachori-recipe-260nw-1508649266.jpg
# Downloaded image 195: https://www.shutterstock.com/image-photo/cooked-bitter-melongourd-karela-sabzi-260nw-1264583032.jpg
# Downloaded image 196: https://www.shutterstock.com/image-photo/aam-ka-murabba-methamba-known-260nw-641289094.jpg
# Downloaded image 197: https://www.shutterstock.com/image-photo/paneer-pulao-fragrant-delicious-mildly-260nw-2082103693.jpg
# Downloaded image 198: https://www.shutterstock.com/image-photo/indian-veg-chapati-wrap-kathi-260nw-1147885403.jpg
# Downloaded image 199: https://www.shutterstock.com/image-photo/mix-vegetable-masala-khichdi-khichuri-600nw-1751130722.jpg
# Downloaded image 200: https://www.shutterstock.com/image-photo/cooked-tikka-tray-mushroom-vigatable-260nw-2403074883.jpg
# Downloaded image 201: https://www.shutterstock.com/image-photo/chole-aloo-paratha-alu-parantha-600nw-1950454744.jpg
# Downloaded image 202: https://www.shutterstock.com/image-photo/daikonradish-mooli-stuffed-paratha-served-260nw-523414639.jpg
# Downloaded image 203: https://www.shutterstock.com/shutterstock/photos/1520877488/display_1500/stock-photo-the-indian-traditional-food-chhole-kulchha-or-kulcha-black-olive-jalapeno-kultcha-amritsari-1520877488.jpg
# Downloaded image 204: https://www.shutterstock.com/image-photo/methi-dal-healthy-flavorful-dish-260nw-2418686343.jpg
# Downloaded image 205: https://www.shutterstock.com/image-photo/arabic-cuisine-egyptian-traditional-green-260nw-2305288599.jpg
# Downloaded image 206: https://www.shutterstock.com/shutterstock/photos/1933814894/display_1500/stock-photo--suji-cheela-chilla-with-spicy-home-style-potatoes-vrat-ki-thali-selective-focus-1933814894.jpg
# Downloaded image 207: https://www.shutterstock.com/image-photo/indian-baby-corn-masalacurry-prepared-600nw-771356068.jpg
# Downloaded image 208: https://www.shutterstock.com/image-photo/fresh-mango-lassi-glasses-on-260nw-2312893983.jpg
# Downloaded image 209: https://www.shutterstock.com/image-photo/famous-indian-cuisines-aloo-paratha-260nw-1206944158.jpg
# Downloaded image 210: https://www.shutterstock.com/image-photo/paksitaniindian-style-dough-bread-filled-600nw-1026682657.jpg
# Downloaded image 211: https://www.shutterstock.com/shutterstock/photos/1037621233/display_1500/stock-photo-paneer-khurchan-stir-fried-indian-cottage-cheese-with-bell-pepper-and-tomatoes-with-indian-spices-1037621233.jpg
# Downloaded image 212: https://www.shutterstock.com/image-photo/boondi-raita-north-indian-side-600nw-2041601327.jpg
# Downloaded image 213: https://www.shutterstock.com/image-photo/semiya-payasam-shewai-sewai-khir-260nw-2087561293.jpg
# Downloaded image 214: https://www.shutterstock.com/image-photo/indian-sweet-dessert-traditional-home-600nw-674011279.jpg
# Downloaded image 215: https://www.shutterstock.com/image-photo/kerala-paratha-type-indian-bread-600nw-788046232.jpg
# Downloaded image 216: https://www.shutterstock.com/image-photo/mughlai-chicken-pulao-tasty-rice-260nw-2394531455.jpg
# Downloaded image 217: https://www.shutterstock.com/image-photo/achari-paneer-tikka-spicy-grilled-260nw-2331213315.jpg
# Downloaded image 218: https://media.istockphoto.com/id/1072893062/photo/beetroot-halwa-garnished-with-pistachio-served-in-a-bowl-selective-focus.jpg?s=612x612&w=0&k=20&c=aBtTxPRC2tjuarBcEF-jepmfQK-bNY7EKnEJApNyayk=
# Downloaded image 219: https://www.shutterstock.com/image-photo/closeup-view-pindi-choleamritsari-chole-260nw-2208000689.jpg
# Downloaded image 220: https://www.shutterstock.com/image-photo/amritsari-paneer-tikka-made-using-260nw-1597285756.jpg
# Downloaded image 221: https://www.shutterstock.com/image-photo/peanut-chikki-balls-brittle-laddu-260nw-2402390839.jpg
# Downloaded image 222: https://www.shutterstock.com/image-photo/crispy-fried-chicken-pork-tonkatsu-260nw-2119781660.jpg
# Downloaded image 223: https://www.shutterstock.com/image-photo/rajma-razma-popular-north-indian-260nw-620241107.jpg
# Downloaded image 224: https://www.shutterstock.com/image-photo/fried-onion-pakora-pyaj-pakoda-260nw-1773809372.jpg
# Downloaded image 225: https://www.shutterstock.com/image-photo/chana-dal-khichdi-famous-delicious-260nw-645802459.jpg
# Downloaded image 226: https://static.toiimg.com/thumb/62775347.cms?imgsize=171877&width=800&height=800
# Downloaded image 227: https://www.shutterstock.com/image-photo/masala-chaas-served-papad-600nw-1035426676.jpg
# Downloaded image 228: https://www.shutterstock.com/image-photo/closeup-creamy-rice-kheerkhir-garnished-260nw-1982444912.jpg
# Downloaded image 229: https://www.shutterstock.com/image-photo/tandoori-aloo-roasted-potatoes-indian-260nw-1390660430.jpg
# Downloaded image 230: https://www.shutterstock.com/image-photo/masala-idli-idly-chilli-coconut-260nw-2089848553.jpg
# Downloaded image 231: https://www.shutterstock.com/image-photo/paneer-stuffed-besan-chilla-cheela-600nw-2203630003.jpg
# Downloaded image 232: https://www.shutterstock.com/image-photo/traditional-indian-fasting-food-recipe-260nw-1932957770.jpg
# Downloaded image 233: https://www.shutterstock.com/image-photo/kada-prasad-atta-north-indian-260nw-1951257394.jpg
# Downloaded image 234: https://www.shutterstock.com/image-photo/seekh-kabab-made-minced-chicken-260nw-2108952152.jpg
# Downloaded image 235: https://www.shutterstock.com/image-photo/besan-ladoo-badam-kaju-600nw-1097047979.jpg
# Downloaded image 236: https://www.shutterstock.com/image-photo/gur-ki-kheer-called-jaggery-260nw-2261200795.jpg
# Downloaded image 237: https://www.shutterstock.com/shutterstock/photos/2070426818/display_1500/stock-photo-choley-chole-masala-or-chana-an-indian-food-made-of-chickpeas-tomatoes-and-cumin-served-with-2070426818.jpg
# Downloaded image 238: https://www.shutterstock.com/image-photo/makki-ki-roti-sarson-ka-260nw-774849826.jpg
# Downloaded image 239: https://www.shutterstock.com/image-photo/chole-aloo-tikki-chaat-simple-600nw-2184141605.jpg
# Downloaded image 240: https://www.shutterstock.com/image-photo/indian-baby-corn-masalacurry-prepared-600nw-771356464.jpg
# Downloaded image 241: https://www.shutterstock.com/image-photo/gobi-pakora-phoolgobi-pakoda-made-260nw-1587548371.jpg
# Downloaded image 242: https://www.shutterstock.com/image-photo/indian-fasting-cuisine-upwas-items-260nw-1931927969.jpg
# Downloaded image 243: https://www.shutterstock.com/image-photo/closeup-homemade-beetroot-poori-fried-260nw-2401092157.jpg
# Downloaded image 244: https://www.shutterstock.com/image-photo/hyderabad-famous-ramazan-special-sweet-260nw-2157642553.jpg
# Downloaded image 245: https://www.shutterstock.com/image-photo/aloo-sandwich-potato-260nw-1717205344.jpg
# Downloaded image 246: https://www.shutterstock.com/image-photo/yogurt-pineapple-ananas-raita-served-260nw-590939285.jpg
# Downloaded image 247: https://www.shutterstock.com/image-photo/traditional-indian-spicy-crunchy-aloo-600nw-1430062514.jpg
# Downloaded image 248: https://media.istockphoto.com/id/506625143/photo/kaju-katli-3.jpg?s=612x612&w=0&k=20&c=q4p0oAhCLNdEeKm8kArRcX7jKgJSmB_HaRzD5_nV7Lg=
# Downloaded image 249: https://www.indianhealthyrecipes.com/wp-content/uploads/2022/02/kadai-mushroom.jpg
# Downloaded image 250: https://www.alcofoods.com/cdn/shop/articles/paneer_labbadar_600x.jpg?v=1683722725
# Downloaded image 251: https://img.freepik.com/free-photo/warm-tomato-soup-serve-bowl_1150-42626.jpg
# Downloaded image 252: https://cdn1.foodviva.com/static-content/food-images/lunch-recipes/lauki-kofta-curry/lauki-kofta-curry.jpg
# Downloaded image 253: https://www.shutterstock.com/image-photo/chole-bhature-north-indian-food-600nw-2238261205.jpg
# Downloaded image 254: https://www.shutterstock.com/image-photo/traditional-ball-shaped-indian-mithai-600nw-2258232827.jpg
# Downloaded image 255: https://thumbs.dreamstime.com/b/indian-paneer-masala-tawa-tikka-vegetarian-curry-dish-side-food-cuisine-bowl-top-down-directly-above-photo-147143557.jpg
# Downloaded image 256: https://img.freepik.com/free-photo/vertical-shot-traditional-indian-paneer-butter-masala-cheese-cottage-curry-black-surface_181624-32001.jpg
# Downloaded image 257: https://www.shutterstock.com/image-photo/chana-dal-organic-tur-split-600nw-1618918879.jpg
# Downloaded image 258: https://media.istockphoto.com/id/1692099288/photo/punjabi-food-sarson-ka-saag-in-bowl-at-food-table.jpg?s=612x612&w=0&k=20&c=lBuOH3O4N52Q8E9viy9kBvN0yVLNfGHLjtKT6I6upJQ=
# Downloaded image 259: https://media.istockphoto.com/id/537532787/photo/rice-with-mung-bean-and-spices-close-up-top-view.jpg?s=612x612&w=0&k=20&c=rfC7JX6fMnaDyBz7Ls9v222ZikKeySxE4W-uPnSPEHw=
# Downloaded image 260: https://www.shutterstock.com/image-photo/moong-dal-halwa-classic-indian-600nw-1778577107.jpg
# Downloaded image 261: https://media.istockphoto.com/id/163064596/photo/gulab-jamun.jpg?s=612x612&w=0&k=20&c=JvJ4AAs-N5pRzzRmVg1lG0talC3QoUt0ZGiO1NKz-kQ=
# Downloaded image 262: https://www.shutterstock.com/image-photo/bharwa-masala-bhindi-stuffed-indian-260nw-1792674436.jpg
# Downloaded image 263: https://media.istockphoto.com/id/1256978725/photo/moong-dal-halwa-or-mung-daal-halva-is-an-indian-sweet-dessert-recipe-garnished-with-dry-fruits.jpg?s=612x612&w=0&k=20&c=3C3TzD6l28y9C_AlobiVHPAsIaNR6xE6rRIGITFepuA=
# Downloaded image 264: https://thumbs.dreamstime.com/b/malai-kofta-curry-black-bowl-dark-slate-background-indian-cuisine-dish-food-potato-paneer-cheese-deep-fried-179415022.jpg
# Downloaded image 265: https://www.shutterstock.com/image-photo/malai-achari-paneer-gravy-made-600nw-1263157405.jpg
# Downloaded image 266: https://media.istockphoto.com/id/1143530040/photo/indian-naan-bread-with-garlic-butter-on-wooden-table.jpg?s=612x612&w=0&k=20&c=71SgbJtnfiHUiud1oGxnhiZsx5nuivWwZt8DlIk8hi0=
# Downloaded image 267: https://media.istockphoto.com/id/1316583859/photo/mango-pickle-or-aam-ka-aachar-or-achar-in-a-bowl-on-wooden-background-theme-with-raw-mangos.jpg?s=612x612&w=0&k=20&c=dQqg5cBILEP-7WJB5LYLYdopSoqZ1ebc9cxXif80DJk=
# Downloaded image 268: https://thumbs.dreamstime.com/b/indian-desert-kheer-made-rice-milk-saffron-nuts-32836407.jpg
# Downloaded image 269: https://www.alcofoods.com/cdn/shop/articles/244e8c208fba8f3f923c9edf1c8a8a00.jpg?v=1684501141
# Downloaded image 270: https://media.istockphoto.com/id/657076158/photo/rajwari-or-rajwadi-sweet-kesar-badam-pista-kulfi-or-ice-cream-candy.jpg?s=612x612&w=0&k=20&c=p0eXjjHOxAawVv32t9a5WOWBEGT-XNMXxbiwtWg1Qs4=
# Downloaded image 271: https://media.istockphoto.com/id/1024585168/photo/paneer-butter-masala-also-known-as-panir-makhani-or-makhanwala-served-in-a-ceramic-or-wooden.jpg?s=612x612&w=0&k=20&c=DbA7ucx0xpS18zO1sFIaAmm41xKF-iIlKxOjbgFZJ1o=
# Downloaded image 272: https://www.shutterstock.com/image-photo/paneer-pasanda-famous-indian-dish-260nw-1876374943.jpg
# Downloaded image 273: https://media.istockphoto.com/id/1292629539/photo/paneer-tikka-masala-is-a-famous-indian-dish-served-over-a-rustic-wooden-background-selective.jpg?s=612x612&w=0&k=20&c=GCvoJ3lBcvvRJmeENmSpa_7rLkh_1OKPaM6gKNYqUGM=
# Downloaded image 274: https://www.shutterstock.com/image-photo/maa-ki-dal-flavoured-tangy-600nw-1274129455.jpg
# Downloaded image 275: https://www.shutterstock.com/image-photo/kashmiri-dum-aloo-spicy-potato-600nw-725768287.jpg
# Downloaded image 276: https://media.istockphoto.com/id/174961905/photo/gobi-aloo-indian-curry-dish.jpg?s=612x612&w=0&k=20&c=Ztm0QBsc4GFm_5yD5v0Dfy5j-Odm1VuMBVhFOEQoO8I=
# Downloaded image 277: https://thumbs.dreamstime.com/b/indian-snack-food-matar-kachori-looks-amazing-seems-very-tasty-lovely-brown-color-indian-snack-food-matar-kachori-197794744.jpg
# Downloaded image 278: https://media.istockphoto.com/id/465049010/photo/stuffed-yellow-and-red-peppers.jpg?s=612x612&w=0&k=20&c=14m9BnzQ7qWJ6byxt6je6xbnF9tlKiKSX6gQqvfeV4Y=
# Downloaded image 279: https://www.shutterstock.com/image-photo/dal-bukhara-rich-creamy-slow-600nw-1639566229.jpg
# Downloaded image 280: https://www.shutterstock.com/shutterstock/photos/263027990/display_1500/stock-photo-amritsari-aloo-kulcha-with-choley-or-stuffed-potato-bread-white-chickpeas-263027990.jpg
# Downloaded image 281: https://www.indianhealthyrecipes.com/wp-content/uploads/2022/07/hara-bhara-kabab.jpg
# Downloaded image 282: https://www.shutterstock.com/image-photo/motichoor-laddu-addu-260nw-2352174411.jpg
# Downloaded image 283: https://media.istockphoto.com/id/452092395/photo/semolina.jpg?s=612x612&w=0&k=20&c=Z6e1Os5aaGVrNIvLRQdH4bxgYEwiTpmhWSPeLW0HR9o=
# Downloaded image 284: https://media.istockphoto.com/id/1370764504/photo/tom-yum-soup-thai-soup-with-prawns-and-rice-noodles-on-black-wooden-table.jpg?s=612x612&w=0&k=20&c=Tws6NmTgJzGhCRuWtHtW5xlt49XYKmzg5TETrcoXGOM=
# Downloaded image 285: https://www.shutterstock.com/image-photo/veg-kolhapuri-black-bowl-on-260nw-1827501401.jpg
# Downloaded image 286: https://www.shutterstock.com/image-photo/indian-masala-fried-okra-bhindi-600nw-328654589.jpg
# Downloaded image 287: https://thumbs.dreamstime.com/b/kalakand-closeup-delicious-fresh-unique-mithai-most-famous-pakistani-indian-peoples-34186313.jpg
# Downloaded image 288: https://media.istockphoto.com/id/1197995878/photo/vegetarian-paneer-biryani-or-panir-pulav-popular-indian-food.jpg?s=1024x1024&w=is&k=20&c=7dK-jnLgVEaGbTBRtwaKiu4lDt9gIfVxbzYhyv-TeFY=
# Downloaded image 289: https://media.istockphoto.com/id/1087995822/photo/indian-food-aloo-curry-masala-potato-cooked-with-spices-and-herbs-in-a-tomato-curry-served-in.jpg?s=612x612&w=0&k=20&c=gaN_zVy3HxS_XJ3Ap9bnQJ0pDtZyteMgcIdtV3bsFek=
# Downloaded image 290: https://media.istockphoto.com/id/1130228942/photo/indian-dal-traditional-indian-soup-lentils-indian-dhal-spicy-curry-in-bowl-spices-herbs.jpg?s=612x612&w=0&k=20&c=ciPGZR4hkLeUL-nRxY4iAh539zYLgUkNz82GG_nJG5A=
# Downloaded image 291: https://www.shutterstock.com/image-photo/semiya-payasam-shewai-sewai-khir-260nw-2087561293.jpg
# Downloaded image 292: https://www.shutterstock.com/image-photo/dahi-bhindi-okra-yogurt-gravy-600nw-1588140682.jpg
# Downloaded image 293: https://thumbs.dreamstime.com/b/sliced-bread-upma-isolated-white-background-india-sliced-bread-upma-isolated-white-background-184709963.jpg
# Downloaded image 294: https://thumbs.dreamstime.com/b/matar-mushroom-curry-onion-garlic-174400448.jpg
# Downloaded image 295: https://www.shutterstock.com/image-photo/sweet-rabdi-lachha-rabri-basundi-260nw-1230247282.jpg
# Downloaded image 296: https://www.shutterstock.com/image-photo/green-peas-curry-matar-masala-260nw-1250569741.jpg
# Downloaded image 297: https://www.shutterstock.com/image-photo/aloo-palak-sabzi-spinach-potatoes-600nw-1294326967.jpg
# Downloaded image 298: https://media.istockphoto.com/id/1331733977/photo/gobi-paratha-or-cauliflower-paratha-is-a-type-of-paratha-or-parantha-or-flatbread-that-is.jpg?s=612x612&w=0&k=20&c=OCXwayRuiVDQW8_2II-cR6FaUfKpg2eRaO_GhB4Jm_A=
# Downloaded image 299: https://st.depositphotos.com/5653638/60062/i/450/depositphotos_600626732-stock-photo-lasooni-palak-recipe-dhaba-style.jpg
# Downloaded image 300: https://www.shutterstock.com/image-photo/pumpkin-kaddu-ki-sabzi-served-260nw-695950867.jpg
# Downloaded image 301: https://www.shutterstock.com/image-photo/dal-makhani-makhni-popular-dish-260nw-1204892983.jpg
# Downloaded image 302: https://st4.depositphotos.com/24035432/25204/i/450/depositphotos_252049976-stock-photo-maalpua-an-indian-sweet-snack.jpg
# Downloaded image 303: https://ministryofcurry.com/wp-content/uploads/2022/04/Aloo-Gobi-4.jpg
# Downloaded image 304: https://media.istockphoto.com/id/1087434658/photo/karela-achar-bitter-gourd-pickle-popular-indian-recipe.jpg?s=612x612&w=0&k=20&c=J2lx0n-UItFF2g6loyWkUEKyppoRpDUCapah5nyM1jI=
# Downloaded image 305: https://www.shutterstock.com/image-photo/kulcha-stuffed-indian-bread-vegetable-600nw-1021207453.jpg
# Downloaded image 306: https://thumbs.dreamstime.com/b/kala-chana-curry-delicious-masala-served-dish-191176665.jpg
# Downloaded image 307: https://media.istockphoto.com/id/1079019508/photo/cashew-curry-indian-kaju-masala-served-in-a-bowl-or-pan-selective-focus.jpg?s=612x612&w=0&k=20&c=dvnO83WfdKcaQd2z-r3fSeYRnsI5KIQ-dRp_Uc3ABkE=
# Downloaded image 308: https://www.shutterstock.com/image-photo/indian-traditional-cuisine-chapati-phooli-600nw-1225846345.jpg
# Downloaded image 309: https://www.shutterstock.com/image-photo/indian-mushroom-masala-curry-naan-260nw-771724963.jpg
# Downloaded image 310: https://www.shutterstock.com/image-photo/paneer-payasam-cottage-cheese-kheer-260nw-2052516326.jpg
# Downloaded image 311: https://www.shutterstock.com/image-photo/sandwich-bread-pakora-pakoda-triangle-600nw-783713575.jpg
# Downloaded image 312: https://www.sharmispassions.com/wp-content/uploads/2013/11/SweetCornPulao1-500x375.jpg
# Downloaded image 313: https://www.shutterstock.com/image-photo/aloo-gobi-masala-curry-chapati-600nw-2089363450.jpg
# Downloaded image 314: https://www.shutterstock.com/image-photo/lassi-drink-indian-traditional-clay-260nw-1766218529.jpg
# Downloaded image 315: https://media.istockphoto.com/id/1358749870/photo/indian-cuisine-aloo-methi-sabji-or-fenugreek-potato-sabji-served-in-a-karahi.jpg?s=612x612&w=0&k=20&c=yvUOXv4BGjCzjNVIDuFxpS1cHjw9cSCYkwl0i3JTz8g=
# Downloaded image 316: https://www.shutterstock.com/image-photo/bread-halwa-called-halva-sheera-260nw-2214958095.jpg
# Downloaded image 317: https://media.istockphoto.com/id/1204866803/photo/indian-potato-patties-aloo-tikki-served-with-yogurt-close-up-in-a-dish-horizontal-top-view.jpg?s=612x612&w=0&k=20&c=G7VRISuqTrUi_1D6O_EtjH2b1VH6H2yR-D9HKD7ro9s=
# Downloaded image 318: https://thumbs.dreamstime.com/b/spicy-fried-potaoes-roasted-cumin-seeds-24939086.jpg
# Downloaded image 319: https://www.shutterstock.com/image-photo/traditional-rice-porridge-payaru-kanji-260nw-427647223.jpg
# Downloaded image 320: https://www.shutterstock.com/image-photo/tahri-tehri-tehiri-tahari-indian-260nw-2184751631.jpg
# Downloaded image 321: https://thumbs.dreamstime.com/z/mathi-sweet-mathari-til-atta-mathri-mathi-sweet-mathari-til-atta-mathri-indian-snack-299110098.jpg
# Downloaded image 322: https://www.shutterstock.com/image-photo/perfect-crispy-jalebi-recipe-how-600nw-1579194580.jpg
# Downloaded image 323: https://media.istockphoto.com/id/980049442/photo/stuffed-paneer-paratha-with-melting-butter-served-with-fresh-cottage-cheese-cubes-and-tomato.jpg?s=612x612&w=0&k=20&c=44IJMPhvdInR4r3JDhHoLsQ3AtF49tnHvnA2eUDz8CQ=
# Downloaded image 324: https://www.shutterstock.com/image-photo/puri-bhaji-poori-masalaaloo-sabzialoo-600nw-1397230991.jpg
# Downloaded image 325: https://media.istockphoto.com/id/1158833399/photo/chilla-or-besan-cheela-or-veg-omelette.jpg?s=612x612&w=0&k=20&c=w_5zMagsjGAhc20Tvnwzpy24TD3sjJWqC7ImrwgnG6w=
# Downloaded image 326: https://www.shutterstock.com/image-photo/mint-onion-paratha-butter-260nw-649041898.jpg
# Downloaded image 327: https://www.shutterstock.com/image-photo/fruit-tangy-by-combining-chilled-600nw-1898179651.jpg
# Downloaded image 328: https://www.shutterstock.com/image-photo/dal-makhani-indian-black-lentil-600nw-2240392383.jpg
# Downloaded image 329: https://www.spiceupthecurry.com/wp-content/uploads/2015/10/carrot-burfi-recipe-9.jpg
# Downloaded image 330: https://thumbs.dreamstime.com/b/veg-burger-aloo-tikki-white-sauce-indian-restaurant-187367162.jpg
# Downloaded image 331: https://www.shutterstock.com/shutterstock/photos/2166625903/display_1500/stock-photo-loki-halwa-or-lauki-halwa-2166625903.jpg
# Downloaded image 332: https://www.shutterstock.com/image-photo/pulao-peas-matar-rice-vegetables-260nw-2379983785.jpg
# Downloaded image 333: https://www.shutterstock.com/image-photo/falooda-faluda-popular-indian-dessert-260nw-1407220004.jpg
# Downloaded image 334: https://www.shutterstock.com/image-photo/namak-para-indian-snack-which-260nw-1417527896.jpg
# Downloaded image 335: https://www.shutterstock.com/image-photo/methi-malai-paneer-creamy-fenugreek-260nw-617034299.jpg
# Downloaded image 336: https://media.istockphoto.com/id/1278584350/photo/veg-kolhapuri-in-black-bowl-on-dark-slate-table-top-indian-vegetable-curry-dish-vegetarian.jpg?s=612x612&w=0&k=20&c=J8J66FYYLs9tupC46-_de1qnASgaEsQn-yk3yW86DJ4=
# Downloaded image 337: https://media.istockphoto.com/id/1250618172/photo/tangy-tamarind-puree-or-imli-paste.jpg?s=612x612&w=0&k=20&c=bml1x7NOgYbp0R7giVbAF4D-s_bneqmkNadkkql-08c=
# Downloaded image 338: https://thumbs.dreamstime.com/b/mango-kulfi-also-spelled-khulfi-qulfi-popular-frozen-dairy-dessert-indian-subcontinent-often-described-as-88813688.jpg
# Downloaded image 339: https://www.shutterstock.com/image-photo/palak-paratha-indian-flat-breads-260nw-1737184049.jpg
# Downloaded image 340: https://media.istockphoto.com/id/1220350725/photo/indian-salted-lemonade-aam-panna.jpg?s=612x612&w=0&k=20&c=viUP0Zb1yyEjJiWG7nKj26n805C0GRoV83fKPO_cYY4=
# Downloaded image 341: https://www.shutterstock.com/image-photo/indian-famous-sweet-food-kala-260nw-433128808.jpg
# Downloaded image 342: https://thumbs.dreamstime.com/b/lauki-chana-dal-north-indian-dish-84414971.jpg
# Downloaded image 343: https://media.istockphoto.com/id/520961869/photo/vegetable-paratha-1.jpg?s=612x612&w=0&k=20&c=t4h_E3Gm8631Dng6SkXWLxPFsG-65BtKxPEOSwWx0NA=
# Downloaded image 344: https://media.istockphoto.com/id/1251472221/photo/lotus-seeds-peas-curry-or-phool-makhana-masala-sabzi.jpg?s=612x612&w=0&k=20&c=s1GhuewzGMZZM5_RU3ltPKR7X-zcz4nj9t0YqoVvaPY=
# Downloaded image 345: https://www.shutterstock.com/image-photo/khoya13-260nw-128129657.jpg
# Downloaded image 346: https://thumbs.dreamstime.com/b/delicious-soan-papadi-served-white-bowl-indian-sweet-snack-halwa-rustic-background-131634289.jpg
# Downloaded image 347: https://www.funfoodfrolic.com/wp-content/uploads/2020/09/Gobi-Tikka-Blog-Thumbnail.jpg
# Downloaded image 348: https://www.shutterstock.com/shutterstock/photos/1263154453/display_1500/stock-photo-paneer-do-pyaza-is-a-popular-punjabi-vegetarian-recipe-using-cubes-of-cottage-cheese-with-lots-of-1263154453.jpg
# Downloaded image 349: https://www.shutterstock.com/image-photo/dahi-wale-aloo-curd-potato-600nw-2134244645.jpg
# Downloaded image 350: https://www.shutterstock.com/image-photo/bajra-jowar-roti-indian-bread-600nw-762078415.jpg
# Downloaded image 351: https://media.istockphoto.com/id/515853026/photo/traditional-rasmalai-or-ras-malai-indian-dessert-bengali-sweet.jpg?s=612x612&w=0&k=20&c=LYftdDAkIa8lVyfmwt8iK-OPSQr2KCcJcYpPhbFtFBk=
# Downloaded image 352: https://www.shutterstock.com/image-photo/bharwa-masala-bhindi-stuffed-indian-600nw-1792674442.jpg
# Downloaded image 353: https://i0.wp.com/vegecravings.com/wp-content/uploads/2018/02/Aloo-Beans-Recipe-Step-By-Step-Instructions.jpg?fit=2044%2C1836&quality=65&strip=all&ssl=1
# Downloaded image 354: https://www.shutterstock.com/image-photo/palak-corn-indian-main-course-600nw-1779972806.jpg
# Downloaded image 355: https://www.shutterstock.com/image-photo/shahi-tukda-double-ka-meetha-260nw-521269165.jpg
# Downloaded image 356: https://media.istockphoto.com/id/501932624/photo/matar-kulcha-or-dried-yellow-peas-chaat.jpg?s=612x612&w=0&k=20&c=RNjvP46I983mMeWmbG0mfi9Lcv2e3Xqoz2oaH-O6Njk=
# ...
# Downloaded image 1039: https://www.shutterstock.com/image-photo/extreme-close-shrimp-crab-cocktail-600nw-283144847.jpg
# Downloaded image 1040: https://www.shutterstock.com/image-photo/smoked-salmon-lemon-dill-top-260nw-1576382782.jpg
# Downloaded image 1041: https://www.eatingwell.com/thmb/BarPqAM5i4yw9lod0L23bUoeKCY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/shrimp-fish-stew-hero-06-729f3e269bb84991a850864cf0b2573d.jpg
# Downloaded image 1042: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRn5PCWr-NYJTwcdlwDw6KC9MpcZjVRbmkUBTgO2jEjLw&s
# Downloaded image 1043: https://www.onceuponachef.com/images/2023/10/Schnitzel-Hero-1.jpg
# Downloaded image 1044: https://www.shutterstock.com/shutterstock/photos/275750720/display_1500/stock-photo-assorted-fish-kebabs-king-big-shrimp-prawn-skewers-wood-board-top-view-isolated-275750720.jpg
# Downloaded image 1045: https://www.allrecipes.com/thmb/JbOeXhnkcEmDNoi2ZlJPk-VL1A4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/6569367-d845cae4ccd64f498a5a6c7fc2adcb88.jpg
# Downloaded image 1046: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTi0WZxBcgFCZpKJBsBL2NJNU2YgLUvZG3Kq7aJ8kGNLg&s
# Downloaded image 1047: https://www.allrecipes.com/thmb/3es9jI2W0huSN_rBCbKgBN-XWjA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/221361-traditional-sauerbraten-beauty-2x1-BP-2927-61e6ad8fae53472ca528c22383113d42.jpg
# Downloaded image 1048: https://staticcookist.akamaized.net/wp-content/uploads/sites/22/2022/09/Currywurst-12-1200x675.jpg
# Downloaded image 1049: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgDWuyJlUfCLkgWBvHH1TbwWOdzSpQumUNs624OSKMZg&s
# Downloaded image 1050: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6wRrKfpcqkgoIyW7mszM7ph18uvUoN94RRptUBJI0eQ&s
# Downloaded image 1051: https://img.taste.com.au/rIljzoV7/taste/2022/09/sri-lankan-beef-kottu-roti-181296-1.jpg
# Downloaded image 1052: https://www.allrecipes.com/thmb/nKyhKSQNe3cWKPlDnV3LvyYgrDI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/609167-fcde3d214a3b4ee49eaf679ad46198d1.jpg
# Downloaded image 1053: https://hungrylankan.com/wp-content/uploads/2020/07/20200705_125604_compress10.jpg
# Downloaded image 1054: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpDpt2zlF5OtkinCLjKj24SAnq48w0talSWMqQIug3vQ&s
# Downloaded image 1055: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHgKZKsUX1zkXxZCSMFu4NE8i_8gJTOje9zdQA5lWOuA&s
# Downloaded image 1056: https://www.simplyrecipes.com/thmb/2GMHFcWEHZGOYbT4eoVCAu2uwsw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2018__07__Seafood-Paella-LEAD-VERTICAL-fc5f1e71baa8484cafa1a106ffaa9c23.jpg
# Downloaded image 1057: https://www.recipetineats.com/wp-content/uploads/2017/07/Beef-Ragu-11a.jpg
# Downloaded image 1058: https://www.supergoldenbakes.com/wordpress/wp-content/uploads/2022/03/Crab_Linguine-1-3.jpg
# Downloaded image 1059: https://www.foodandwine.com/thmb/YRIxnDqYxK66UUgArW6_57jG9AE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/white-fish-risotto-XL-RECIPE2017-8919425b28c246cb976b20dceefbf1c0.jpg
# Downloaded image 1060: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2a72r3X7Pdbx0svN3hfrM3yiK7MOMXzCwSBS3Fe-1XA&s
# Downloaded image 1061: https://thumbs.dreamstime.com/z/mixed-grilled-meat-platter-assorted-delicious-grilled-meat-vegetable-pepper-sauce-vegetables-91013667.jpg
# Downloaded image 1062: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrgu9zPF3pTsGpRU9LgCd5fZNLUqYHQFtLZvKRiulEvQ&s
# Downloaded image 1063: https://www.shutterstock.com/shutterstock/photos/530203870/display_1500/stock-photo-grilled-tiger-shrimps-with-spice-and-lemon-grilled-seafood-530203870.jpg
# Downloaded image 1064: https://www.wellplated.com/wp-content/uploads/2020/02/Baked-Fish-En-Papillote.jpg
# Downloaded image 1065: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQtOvuWMRrJWAfT5R3Wvirf9Q4PV8EK9_rpCWh4DTjNXQ&s
# Downloaded image 1066: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRsdX0K-yRyxY51-R5gJl1dPyeqGjCnfV6nPiU86gT15A&s
# Downloaded image 1067: https://www.simplyrecipes.com/thmb/kO2yxG-lT4gNjwLAREAbrspEsgM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2011__11__italian-meatballs-horiz-c-1800-e83b24e913364fd6b867805335961d65.jpg
# Downloaded image 1068: https://farm8.staticflickr.com/7537/16035876500_6093dc1419_b.jpg
# Downloaded image 1069: https://www.shutterstock.com/image-photo/chicken-soup-vegetables-white-bowl-600nw-1575499510.jpg
# Downloaded image 1070: https://www.shutterstock.com/image-photo/closeup-vegetable-beef-soup-red-260nw-2106758441.jpg
# Downloaded image 1071: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTA_rqEnujXosZwBTVN9N0x32mB0MC8kVNBuqJll1JdIA&s
# Downloaded image 1072: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRN9RyORoNT2vU57lEeJLHoDZz2JUIucTQCFAJOBx7pvg&s
# Downloaded image 1073: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTL37_5Gd4QAm2uC9SXlXbQlfexZl35Wv0f2QZPyql5dQ&s
# Downloaded image 1074: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2vN6I4M3c_ckbtRiGHpPvUvRI6rVEF1t_yyW31ISYfA&s
# Downloaded image 1075: https://www.shutterstock.com/image-photo/close-chicken-mushroom-pie-on-600nw-1965422818.jpg
# Downloaded image 1076: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR-GWRP2ElEgmnFlVQurJblsErncTm4bGxIrMXFwMHlGg&s
# Downloaded image 1077: https://images.immediate.co.uk/production/volatile/sites/30/2020/08/beef-stout-stew-a6d9c78.jpg?quality=90&resize=440,400
# Downloaded image 1078: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReOsUcdJUBwPN_hu78mPFXOxrC07DHDln0-0Shwn08LA&s
# Downloaded image 1079: https://www.simplyrecipes.com/thmb/LnLG3RlDzwwfH6U6N__eElWYSpQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2011__12__chicken-liver-pate-horiz-a-1200-5d5777ad8f974b96a1f557fbc9e7429d.jpg
# Downloaded image 1080: https://cdn.apartmenttherapy.info/image/upload/f_jpg,q_auto:eco,c_fill,g_auto,w_1500,ar_1:1/k%2FPhoto%2FRecipes%2F2022-01_scotch-egg%2F2022-01-05_ATK-0996
# Downloaded image 1081: https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Fish_and_chips_blackpool.jpg/800px-Fish_and_chips_blackpool.jpg
# Downloaded image 1082: https://handletheheat.com/wp-content/uploads/2015/06/beef-empanadas-SQUARE.jpg
# Downloaded image 1083: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6e4BTufu8xI9sr4NGIyKjKPORZVneExmHEQM6xBny1g&s
# Downloaded image 1084: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQMsdEMR1VNoYX5_qmPhLJDIN_joFN_GzffdmXldQEeqw&s
# Downloaded image 1085: https://www.shutterstock.com/image-photo/lobster-roll-on-slate-surface-260nw-267633224.jpg
# Downloaded image 1086: https://www.allrecipes.com/thmb/WSSoRAz2IygrMPkiJxHPbt9gqMg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/8635-southern-fried-chicken-ddmfs_4x3-90736ab31a7a4bb59eb04e2380ccebe7.jpg
# Downloaded image 1087: https://www.allrecipes.com/thmb/GwdML2o-xsFGnHTEp-uy7RWMEOc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/166638-baked-buffalo-wings-ddmfs-beauty-3x4-90787930d20b402e9dde79c22fced332.jpg
# Downloaded image 1088: https://rhubarbandcod.com/wp-content/uploads/2022/06/The-Classic-Cheeseburger-1.jpg
# Downloaded image 1089: https://d1e3z2jco40k3v.cloudfront.net/-/media/5a628a163bab440383da150ea39de9e7.ashx?h=800&amp;la=en-us
# Downloaded image 1090: https://www.shutterstock.com/shutterstock/photos/1295330575/display_1500/stock-photo-hot-baked-potato-topped-with-bacon-green-onions-and-cheddar-cheese-1295330575.jpg
# Downloaded image 1091: https://www.allrecipes.com/thmb/u2jle7sEiO5vkLrIGar0TakjY8s=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/20858-best-ever-jalapeno-poppers-DDMFS-4x3-69772a3d60cd4a63b6dfac0ff415db51.jpg
# Downloaded image 1092: https://www.shutterstock.com/image-photo/homemade-spicy-deviled-eggs-paprika-600nw-256419517.jpg
# Downloaded image 1093: https://www.shutterstock.com/image-photo/dish-delicious-deepfried-calamari-rings-600nw-2344388995.jpg
# Downloaded image 1094: https://www.wellplated.com/wp-content/uploads/2023/05/Oven-Fried-Chicken-Tenders-Recipe.jpg
# Downloaded image 1095: https://www.shutterstock.com/image-photo/plate-delicious-bacon-wrapped-scallops-600nw-1266733525.jpg
# Downloaded image 1096: https://www.shutterstock.com/image-photo/homemade-fried-mozzarella-sticks-marinara-260nw-150708950.jpg
# Downloaded image 1097: https://hips.hearstapps.com/hmg-prod/images/crab-cakes-index-64e7cee7d4dda.jpg?crop=0.8891500963202403xw:1xh;center,top&resize=1200:*
# Downloaded image 1098: https://food.fnr.sndimg.com/content/dam/images/food/fullset/2004/4/21/0/bw2b09_shrimp_cocktail.jpg.rend.hgtvcom.1280.1280.suffix/1557928675507.jpeg
# Downloaded image 1099: https://www.recipetineats.com/wp-content/uploads/2019/01/Baked-Buffalo-Wings_0.jpg
# Downloaded image 1100: https://i2.wp.com/www.downshiftology.com/wp-content/uploads/2023/10/Crab-Stuffed-Mushrooms-main-2.jpg
# Downloaded image 1101: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSC1qaIdAl_qz5VUR9yWiDPmWJS1Ck_986wKb1I0nfm3A&s
# Downloaded image 1102: https://static.emerils.com/styles/wmax-600-sq/public/Fritters.jpg?itok=WQSDmvwK
# Downloaded image 1103: https://www.simplyrecipes.com/thmb/4m-cJOBzwHvJOhtC8h6tSPbG1_8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Smoked-Salmon-Crostini-LEAD-02-a2a2492d16da44378aa1d6a826e2e9a2.jpg
# Downloaded image 1104: https://www.shutterstock.com/shutterstock/photos/1818536438/display_1500/stock-photo-chinese-crab-rangoon-fried-wontons-on-plate-with-red-sauce-1818536438.jpg
# Downloaded image 1105: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSrm-P60BfihCxXgpvjk9Ge1PwtqyjjUDfDy4Bpr1UQg&s
# Downloaded image 1106: https://www.allrecipes.com/thmb/BgOwxHqiCf3EgRxsxPTcn9rF9CA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/8149211-c9122b5df35d42c6894d05bcebce2c72.jpg
# Downloaded image 1107: https://www.simplyrecipes.com/thmb/Gfmp44usm9wMrdjyyLALIi09NWo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Corn-Crabmeat-Chowder-LEAD-5-ac3885c7ef2c4248972ee2a908f38887.jpg
# Downloaded image 1108: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTc1d6ZjpfTo2xw_puvDz8oG_udKPRkuWZdgqIB6K-t3A&s
# Downloaded image 1109: https://media.istockphoto.com/id/137152748/photo/chicken-fillet.jpg?s=612x612&w=0&k=20&c=N-YHf2m5Bisynn-eurqoKnHAen13YHswHZzdtu-1ovw=
# Downloaded image 1110: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0wWe_MkwqKPz3m-PcdgWQkRvWIqVnGzgWgLuQs-4Nbw&s
# Downloaded image 1111: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTVbiOGzCGNNq-5gLdshZi7BjUwoZtUUgLg5iq7ZVipDw&s
# Downloaded image 1112: https://www.shutterstock.com/image-photo/homemade-creamy-oysters-rockefeller-cheese-260nw-385915237.jpg
# Downloaded image 1113: https://www.shutterstock.com/image-photo/pan-delicious-fresh-homemade-cajun-260nw-488586964.jpg
# Downloaded image 1114: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQT9jw4XQKMTNDhYbqwKQvF0o2dIqtyfHwBVB8oeul0cg&s
# Downloaded image 1115: https://mojo.generalmills.com/api/public/content/JkWfbsGspk-1188E3B3qgw_gmi_hi_res_jpeg.jpeg?v=3585536b&t=466b54bb264e48b199fc8e83ef1136b4
# Downloaded image 1116: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjF_nHPb2568AQZfunPSBgoY502__ua4TbuHb0wtiJ6g&s
# Downloaded image 1117: https://www.thespruceeats.com/thmb/KCt7H7pD7MJ0LeTbg6kLB8OAwPM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/italian-buttery-garlic-crab-bruschetta-1300497-hero-04-d0526c0eb2fc4904ba36199a09c4df38.jpg
# Downloaded image 1118: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrPp5LRSjDHJ9VDv7y6M74E1Z25TlrOMT2QMpU5uBBjQ&s
# Downloaded image 1119: https://images.immediate.co.uk/production/volatile/sites/30/2021/04/Crab-and-saffron-risotto-3360182.jpg?resize=768,574
# Downloaded image 1120: https://www.shutterstock.com/image-photo/frying-pan-tasty-trout-fish-600nw-675807403.jpg
# Downloaded image 1121: https://img.sndimg.com/food/image/upload/q_92,fl_progressive,w_1200,c_scale/v1/img/recipes/35/19/32/pic66kbuy.jpg
# Downloaded image 1122: https://i2.wp.com/www.downshiftology.com/wp-content/uploads/2023/07/Crab-Salad-main.jpg
# Downloaded image 1123: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQiSGljBFeOD3ISl5IXZib_fLq6n9E0PhxqZ6ngsNpBBQ&s
# Downloaded image 1124: https://www.allrecipes.com/thmb/SoBuPU73KcbYHl3Kp3j8Xx4A3fc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/8805-CrispyFriedChicken-mfs-3x2-072-d55b8406d4ae45709fcdeb58a04143c2.jpg
# Downloaded image 1125: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRI7Mzn9asApEpnZ-S-0DigbkHiOxMyqILHikxtfm332g&s
# Downloaded image 1126: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRgoFSOCFqm3tI5PNyrVqNz17br6Rnhh98MtmovKdI5A&s
# Downloaded image 1127: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQu4ewENbIFyzCYY-T1HHsAdigOTPGHHq2jn4UuXp8mDA&s
# Downloaded image 1128: https://hips.hearstapps.com/delish/assets/17/04/1485369256-chicken-parm-bitesl1.jpg
# Downloaded image 1129: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQz0jIZrYBRziL-4xbvBNkfAaYzucq81h25MESl6GT6lQ&s
# Downloaded image 1130: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6ke8MgoDtp2x1c09zt98CF516Sp_0UQHQ1mnJjiKo-g&s
# Downloaded image 1131: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpL1Lcvom8KZQZKuJxGHgzMAwfz-pgFs8uY6eAZtUjZg&s
# Downloaded image 1132: https://www.indianhealthyrecipes.com/wp-content/uploads/2021/07/egg-fried-rice-recipe.jpg
# Downloaded image 1133: https://www.recipetineats.com/wp-content/uploads/2016/04/Thai-Fish-Cakes-landscape.jpg
# Downloaded image 1134: https://www.shutterstock.com/image-photo/thai-style-spicy-chicken-wings-260nw-242109895.jpg
# Downloaded image 1135: https://www.shutterstock.com/image-photo/pad-thai-600nw-366360143.jpg
# Downloaded image 1136: https://www.recipetineats.com/wp-content/uploads/2019/02/Thai-Green-Curry_5.jpg
# Downloaded image 1137: https://www.shutterstock.com/image-photo/thai-drunken-noodles-pad-kee-600nw-1655549911.jpg
# Downloaded image 1138: https://www.shutterstock.com/image-photo/crab-fried-rice-thai-style-600nw-1718552239.jpg
# Downloaded image 1139: https://www.shutterstock.com/image-photo/tom-yum-goong-thai-hot-260nw-497390089.jpg
# Downloaded image 1140: https://www.licious.in/blog/wp-content/uploads/2021/03/egg-pakoda-1-600x600.jpg
# Downloaded image 1141: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWMgIA4SQQixDsckIkN6Df0J2z2vV-fNgcO_ie_wadlw&s
# Downloaded image 1142: https://www.licious.in/blog/wp-content/uploads/2020/12/Tandoori-Fish.jpg
# Downloaded image 1143: https://static.toiimg.com/photo/75356205.cms
# Downloaded image 1144: https://natashaskitchen.com/wp-content/uploads/2020/10/Egg-Rolls-4.jpg
# Downloaded image 1145: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTcYYe4tv1G83wa7oNF43W9KM6sGlkFMn98adwUniqKeA&s
# Downloaded image 1146: https://www.masala.tv/wp-content/uploads/2021/06/Nawabi-Fish-Karahii.jpg
# Downloaded image 1147: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKIgAPyXdkkkAeW1Ms45SLO6_ZAh0uxcgRshskJfdS8w&s
# Downloaded image 1148: https://img-global.cpcdn.com/recipes/e456480d88c6b5ad/400x400cq70/photo.jpg
# Downloaded image 1149: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZMI6ECr9h7fdJktWeXOkqVNfqPSk-zrkQ9F-fJ_5hog&s
# Downloaded image 1150: https://www.simplyrecipes.com/thmb/RrIT5GcxpHru0ZHis39-wyXADNg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2017__12__2017-12-Chicken-Fried-Rice-3-c98348ac2e4545d9a3e637a780f09b70.jpg
# Downloaded image 1151: https://www.allrecipes.com/thmb/nKyhKSQNe3cWKPlDnV3LvyYgrDI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/609167-fcde3d214a3b4ee49eaf679ad46198d1.jpg
# Image download process completed.

# %%
# Download and save images by cuisine
image_directory = 'Recfusion_img/'

# %%
import os

# Define image directory and ensure it exists
image_directory = 'Recfusion_img/'
os.makedirs(image_directory, exist_ok=True)

# ...

# Loop through the dataset and download images
for index, row in data.iterrows():
    image_url = row['image_url']
    cuisine = row['cuisine']
    image_path = f'{image_directory}/{cuisine}/{index}.jpg'

    try:
        os.makedirs(os.path.dirname(image_path), exist_ok=True)  # Ensure the cuisine subdirectory exists
        response = requests.get(image_url)
        with open(image_path, 'wb') as f:
            f.write(response.content)
    except Exception as e:
        print(f"Error downloading image for index {index}: {e}")

# %%
# Load the dataset
data = pd.read_csv('fusionrecipe.csv')

# %%
# for cuisine in recipes_df['cuisine'].unique():
#     cuisine_df = recipes_df[recipes_df['cuisine'] == cuisine]
#     for index, row in cuisine_df.iterrows():
#         image_url = row['image_url']
#         image_path = f'{image_directory}/{cuisine}/{index}.jpg'
#         response = requests.get(image_url)
#         with open(image_path, 'wb') as f:
#             f.write(response.content)

# %%
from PIL import Image

# Function to preprocess image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.convert('RGB')  # Convert to RGB format
    image = image.resize((224, 224))  # Resize to a consistent size
    return image

# Apply image preprocessing
for index, row in data.iterrows():
    image_path = f'{image_directory}/{row["cuisine"]}/{index}.jpg'
    processed_image = preprocess_image(image_path)
    processed_image.save(image_path)  # Overwrite the original image with the preprocessed one

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset  # Add this line
from torchvision import transforms

# Define image transformations (resize, normalize, etc.)
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the image to 224x224 pixels
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize the image
])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torchvision import transforms
from PIL import Image

# Create a dictionary to map cuisine names to unique IDs
cuisine_to_id = {cuisine: idx for idx, cuisine in enumerate(data['cuisine'].unique())}

# Create a new 'cuisine_id' column based on the mapping
data['cuisine_id'] = data['cuisine'].map(cuisine_to_id)

# Define the RecipeCNN class
class RecipeCNN(nn.Module):
    def __init__(self, num_classes):
        super(RecipeCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(16 * 112 * 112, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, num_classes)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = x.view(-1, 16 * 112 * 112)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Define image transformations
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load and preprocess images
image_data = [image_transforms(Image.open(f'{image_directory}/{row["cuisine"]}/{index}.jpg')) for index, row in data.iterrows()]
image_data = torch.stack(image_data)
image_labels = torch.tensor(data['cuisine_id'].values, dtype=torch.long)

# Create a custom dataset class
class RecipeImageDataset(torch.utils.data.Dataset):
    def __init__(self, data, labels, transform=None):
        self.data = data
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Create a data loader for the CNN model
image_dataset = RecipeImageDataset(image_data, image_labels)
image_loader = DataLoader(image_dataset, batch_size=32, shuffle=True)

# Initialize and train the CNN model
cnn_model = RecipeCNN(num_classes=data['cuisine_id'].nunique())
optimizer = optim.Adam(cnn_model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

num_epochs = 10
for epoch in range(num_epochs):
    for images, labels in image_loader:
        optimizer.zero_grad()
        outputs = cnn_model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

# %%
# Extract image features using the trained CNN model
def extract_image_features(image_data):
    with torch.no_grad():
        image_features = cnn_model(image_data)
    return image_features

# %%
batch_size = 32
num_batches = len(image_data) // batch_size + 1

# %%
image_features = []
cnn_model.eval()
# Out:
# RecipeCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=200704, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=59, bias=True)
# )

# %%
with torch.no_grad():
    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size
        batch_images = image_data[start_idx:end_idx]
        batch_features = cnn_model(batch_images)

        image_features.append(batch_features)

# %%
# Concatenate the features from all batches
image_features = torch.cat(image_features)

# %%
import pickle
# create an iterator object with write permission - model.pkl
with open('cnn_model', 'wb') as files:
    pickle.dump(cnn_model, files)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarities between recipes based on image features
image_similarity_matrix = cosine_similarity(image_data.view(image_data.size(0), -1))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Function to calculate item-item cosine similarity
def item_item_similarity(image_features):
    return cosine_similarity(image_features)

# %%
# You can optionally normalize the similarity matrix
from sklearn.preprocessing import normalize
image_similarity_matrix_normalized = normalize(image_similarity_matrix, axis=1)

# %%
def recommend_recipes_by_image_similarity(recipe_id, num_recommendations=5):
    # Get the similarity scores for the target recipe
    target_similarity_scores = image_similarity_matrix_normalized[recipe_id]

    # Get the indices of recipes sorted by image similarity (excluding the target recipe itself)
    similar_recipe_indices = sorted(range(len(target_similarity_scores)), key=lambda i: target_similarity_scores[i], reverse=True)[1:]

    # Get the top N recommended recipe indices
    recommended_indices = similar_recipe_indices[:num_recommendations]

    # Return the recommended recipes
    recommended_recipes = data.iloc[recommended_indices]
    return recommended_recipes[['name', 'calories & servings', 'ingredients', 'instruction']]

# %%
# Example: Recommend recipes similar to recipe at index 0
recommended_recipes = recommend_recipes_by_image_similarity(0, num_recommendations=5)
print("Recommended Recipes based on Image Similarity:")
print(recommended_recipes)
# Out:
# Recommended Recipes based on Image Similarity:
#                name calories & servings  \
# 572     Mango Curry             250 & 4
# 155   Carrot Halwa              512 & 3
# 606    Mutton Curry             271 & 3
# 293      Bread Upma             200 & 4
# 645  Chicken Lazeez             375 & 3
#
#                                            ingredients  \
# 572  2 ripe mangoes, peeled and diced , 1 onion, fi...
# 155  4 C Carrots, peeled - thickly grated, 1 Tbsp G...
# 606  Mutton – 500 gms, boneless, cleaned, washed,On...
# 293  6 slices of bread, preferably whole wheat , 2 ...
# 645  500g chicken pieces (boneless or with bones),1...
#
#                                            instruction
# 572  Heat the vegetable oil in a large skillet over...
# 155  In a non stick wide bottomed pot, add ghee, as...
# 606  Heat oil or ghee in a large, heavy-bottomed po...
# 293  Trim the edges of the bread slices and cut the...
# 645  Heat oil or ghee in a pan and add cumin seeds....

# %%
type(image_similarity_matrix_normalized)
# Out:
# numpy.ndarray

# %%
dump_arr = image_similarity_matrix_normalized.tolist()

# %%
import json
with open('image_features.json', 'w') as json_file:
    json.dump(dump_arr, json_file)

# %%
import json
import numpy as np

# %%
with open('C:/Users/Lenovo/image_features.json', 'r') as json_file:
    loaded_data = json.load(json_file)

# %%
import pandas as pd
import requests

data = pd.read_csv('fusionrecipe.csv')

# %%
def recommend_recipes_by_image_similarity(recipe_id, num_recommendations=5):
    # Get the similarity scores for the target recipe
    target_similarity_scores = loaded_data[recipe_id]

    # Get the indices of recipes sorted by image similarity (excluding the target recipe itself)
    similar_recipe_indices = sorted(range(len(target_similarity_scores)), key=lambda i: target_similarity_scores[i], reverse=True)[1:]

    # Get the top N recommended recipe indices
    recommended_indices = similar_recipe_indices[:num_recommendations]

    # Return the recommended recipes
    recommended_recipes = data.iloc[recommended_indices]
    return recommended_recipes[['name','calories & servings', 'ingredients', 'instruction']]

# %%
# Example: Recommend recipes similar to recipe at index 0
recommended_recipes = recommend_recipes_by_image_similarity(0, num_recommendations=5)
print("Recommended Recipes based on Image Similarity:")
print(recommended_recipes)
# Out:
# Recommended Recipes based on Image Similarity:
#                name calories & servings  \
# 572     Mango Curry             250 & 4
# 155   Carrot Halwa              512 & 3
# 606    Mutton Curry             271 & 3
# 293      Bread Upma             200 & 4
# 645  Chicken Lazeez             375 & 3
#
#                                            ingredients  \
# 572  2 ripe mangoes, peeled and diced , 1 onion, fi...
# 155  4 C Carrots, peeled - thickly grated, 1 Tbsp G...
# 606  Mutton – 500 gms, boneless, cleaned, washed,On...
# 293  6 slices of bread, preferably whole wheat , 2 ...
# 645  500g chicken pieces (boneless or with bones),1...
#
#                                            instruction
# 572  Heat the vegetable oil in a large skillet over...
# 155  In a non stick wide bottomed pot, add ghee, as...
# 606  Heat oil or ghee in a large, heavy-bottomed po...
# 293  Trim the edges of the bread slices and cut the...
# 645  Heat oil or ghee in a pan and add cumin seeds....

# %%
def evaluate_recommendations(loaded_data, data, num_recommendations=5):
    # List to store evaluation metrics for each recipe
    recalls = []
    mrrs = []
    mapn = []
    ndcg = []

    # Iterate over each recipe
    for recipe_id in loaded_data.keys():
        # Get the similarity scores for the target recipe
        target_similarity_scores = loaded_data[recipe_id]

        # Get the indices of recipes sorted by image similarity (excluding the target recipe itself)
        similar_recipe_indices = sorted(range(len(target_similarity_scores)), key=lambda i: target_similarity_scores[i], reverse=True)[1:]

        # Get the top N recommended recipe indices
        recommended_indices = similar_recipe_indices[:num_recommendations]

        # True relevant items
        relevant_recipes = set(data[data.index == recipe_id].index.values)

        # Predicted recommended items
        recommended_recipes = set(data.iloc[recommended_indices].index.values)

        # Calculate recall at N
        recall = len(relevant_recipes.intersection(recommended_recipes)) / len(relevant_recipes)
        recalls.append(recall)

        # Calculate reciprocal rank
        reciprocal_rank = 0
        for i, idx in enumerate(recommended_indices):
            if idx in relevant_recipes:
                reciprocal_rank = 1 / (i + 1)
                break
        mrrs.append(reciprocal_rank)

        # Calculate precision at N
        precision = len(relevant_recipes.intersection(recommended_recipes)) / num_recommendations
        mapn.append(precision)

        # Calculate discounted cumulative gain at N
        dcg = 0
        for i, idx in enumerate(recommended_indices):
            if idx in relevant_recipes:
                dcg += 1 / np.log2(i + 2)
        idcg = sum([1 / np.log2(i + 2) for i in range(min(len(relevant_recipes), num_recommendations))])
        ndcg.append(dcg / idcg)

    

# Example usage:
# avg_recall, avg_mrr, avg_mapn, avg_ndcg = evaluate_recommendations(loaded_data, data, num_recommendations=5)
# print("Average Recall@5:", avg_recall)
# print("Average MRR:", avg_mrr)
# print("Average MAP@5:", avg_mapn)
# print("Average NDCG@5:", avg_ndcg)

# %%
avg_recall, avg_mrr, avg_mapn, avg_ndcg = evaluate_recommendations(loaded_data, data, num_recommendations=10)
print("Average Recall@10:", avg_recall)
print("Average MRR:", avg_mrr)
print("Average MAP@10:", avg_mapn)
print("Average NDCG@10:", avg_ndcg)
# Out:
# Average Recall@10: 0.008680555555555554
# Average MRR: 1.0
# Average MAP@10: 1.0
# Average NDCG@10: 1.0

# %%
def evaluate_recommendations(loaded_data, data, num_recommendations=5):
    # List to store evaluation metrics for each recipe
    recalls = []
    mrrs = []
    mapn = []
    ndcg = []

    # Iterate over each recipe's similarity scores
    for target_similarity_scores in loaded_data:
        # Get the indices of recipes sorted by image similarity (excluding the target recipe itself)
        similar_recipe_indices = sorted(range(len(target_similarity_scores)), key=lambda i: target_similarity_scores[i], reverse=True)[1:]

        # Get the top N recommended recipe indices
        recommended_indices = similar_recipe_indices[:num_recommendations]

        # True relevant items
        relevant_recipes = set(data.index)

        # Predicted recommended items
        recommended_recipes = set(data.iloc[recommended_indices].index)

        # Calculate recall at N
        recall = len(relevant_recipes.intersection(recommended_recipes)) / len(relevant_recipes)
        recalls.append(recall)

        # Calculate reciprocal rank
        reciprocal_rank = 0
        for i, idx in enumerate(recommended_indices):
            if idx in relevant_recipes:
                reciprocal_rank = 1 / (i + 1)
                break
        mrrs.append(reciprocal_rank)

        # Calculate precision at N
        precision = len(relevant_recipes.intersection(recommended_recipes)) / num_recommendations
        mapn.append(precision)

        # Calculate discounted cumulative gain at N
        dcg = 0
        for i, idx in enumerate(recommended_indices):
            if idx in relevant_recipes:
                dcg += 1 / np.log2(i + 2)
        idcg = sum([1 / np.log2(i + 2) for i in range(min(len(relevant_recipes), num_recommendations))])
        ndcg.append(dcg / idcg)

    # Compute average metrics
    avg_recall = np.mean(recalls)
    avg_mrr = np.mean(mrrs)
    avg_mapn = np.mean(mapn)
    avg_ndcg = np.mean(ndcg)

    return avg_recall, avg_mrr, avg_mapn, avg_ndcg

# Example usage:
avg_recall, avg_mrr, avg_mapn, avg_ndcg = evaluate_recommendations(loaded_data, data, num_recommendations=10)
print("Average Recall@10:", avg_recall)
print("Average MRR:", avg_mrr)
print("Average MAP@10:", avg_mapn)
print("Average NDCG@10:", avg_ndcg)
# Out:
# Average Recall@10: 0.008680555555555554
# Average MRR: 1.0
# Average MAP@10: 1.0
# Average NDCG@10: 1.0
